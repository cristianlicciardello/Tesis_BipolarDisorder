# %% [markdown]
# # Demographics of Academy Awards Winners
# ![](Data/Oscars/dolby.jpg)

# %% [markdown]
# ### To begin, we will be importing the libraries we will be using for this example:
#
# * **pandas**: To provide high-performance, easy-to-use data structures and data analysis tools for the Python programming
#
# * **numpy**: To add support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
#
# * **matplotlib**: Plotting library for the Python programming language and its numerical mathematics extension NumPy.
#
# #### We will be also using _%matplotlib inline_, to have the output of plotting commands displayed inline within frontends like the Jupyter notebook, directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
"""
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
"""
# Out:
# '\nfrom pydrive.auth import GoogleAuth\nfrom pydrive.drive import GoogleDrive\nfrom google.colab import auth\nfrom oauth2client.client import GoogleCredentials\n\n# Authenticate and create the PyDrive client\nauth.authenticate_user()\ngauth = GoogleAuth()\ngauth.credentials = GoogleCredentials.get_application_default()\ndrive = GoogleDrive(gauth)\n'

# %% [markdown]
# #### Now we are ready to read the first file. As data is in csv format, we will be using the read_csv() function, which allows us to parse and load data into a dataframe (in memory) easily.
#
# #### To see what we just read, we will be using the head() function. We can indicate the number of rows as a parameter, or by default it will show 5 rows.
# ####

# %%
"""
id='1IYecdd6KegNcDM-Az6DtDPBCFeNpiw5D'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('Oscars-demographics-DFE.csv')
"""
# Out:
# "\nid='1IYecdd6KegNcDM-Az6DtDPBCFeNpiw5D'\ndownloaded = drive.CreateFile({'id': id})\ndownloaded.GetContentFile('Oscars-demographics-DFE.csv')\n"

# %%
# Load the Data and take a quick look.
oscars_demographics = pd.read_csv('Oscars-demographics-DFE.csv', encoding='latin-1')
oscars_demographics.tail()
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 436  670946276    False   finalized                   3      2/10/15 2:00
# 437  670946299    False   finalized                   3      2/10/15 2:04
# 438  670964912    False   finalized                   3      2/10/15 2:03
# 439  670964956    False   finalized                   3      2/10/15 2:01
# 440  670972898    False   finalized                   3      2/10/15 2:01
#
#               birthplace  birthplace:confidence date_of_birth  \
# 436      London, England                    1.0      7-Mar-71
# 437  Manchester, England                    1.0     20-Oct-56
# 438          Chicago, Il                    1.0     26-Jul-22
# 439           Laurel, Ne                    1.0     31-Aug-28
# 440           Nevada, Mo                    1.0      5-Aug-06
#
#      date_of_birth:confidence race_ethnicity  ...                    award  \
# 436                       1.0          White  ...  Best Supporting Actress
# 437                       1.0          White  ...            Best Director
# 438                       1.0          White  ...    Best Supporting Actor
# 439                       1.0          White  ...    Best Supporting Actor
# 440                       1.0          White  ...            Best Director
#
#                                         biourl  birthplace_gold  \
# 436  http://www.nndb.com/people/309/000032213/              NaN
# 437  http://www.nndb.com/people/887/000044755/              NaN
# 438  http://www.nndb.com/people/224/000032128/              NaN
# 439  http://www.nndb.com/people/764/000022698/              NaN
# 440  http://www.nndb.com/people/704/000024632/              NaN
#
#     date_of_birth_gold                             movie         person  \
# 436                NaN             The Constant Gardener   Rachel Weisz
# 437                NaN               Slumdog Millionaire    Danny Boyle
# 438                NaN           All the President's Men  Jason Robards
# 439                NaN                        Affliction   James Coburn
# 440                NaN  The Treasure of the Sierra Madre    John Huston
#
#      race_ethnicity_gold religion_gold sexual_orientation_gold  \
# 436                  NaN           NaN                     NaN
# 437                  NaN           NaN                     NaN
# 438                  NaN           NaN                     NaN
# 439                  NaN           NaN                     NaN
# 440                  NaN           NaN                     NaN
#
#     year_of_award_gold
# 436                NaN
# 437                NaN
# 438                NaN
# 439                NaN
# 440                NaN
#
# [5 rows x 27 columns]

# %%
oscars_short = pd.read_csv('Oscars-demographics-DFE.csv', encoding='latin-1',\
                usecols=['birthplace', 'date_of_birth', 'race_ethnicity', 'religion','sexual_orientation', 'year_of_award', 'award', 'movie', 'person'])
oscars_short.tail()
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 436      London, England      7-Mar-71          White          Jewish
# 437  Manchester, England     20-Oct-56          White  Roman Catholic
# 438          Chicago, Il     26-Jul-22          White              Na
# 439           Laurel, Ne     31-Aug-28          White              Na
# 440           Nevada, Mo      5-Aug-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
# 438           Straight           1977    Best Supporting Actor
# 439           Straight           1999    Best Supporting Actor
# 440           Straight           1949            Best Director
#
#                                 movie         person
# 436             The Constant Gardener   Rachel Weisz
# 437               Slumdog Millionaire    Danny Boyle
# 438           All the President's Men  Jason Robards
# 439                        Affliction   James Coburn
# 440  The Treasure of the Sierra Madre    John Huston

# %%
# Information about the dataset
oscars_demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   _unit_id                       441 non-null    int64
#  1   _golden                        441 non-null    bool
#  2   _unit_state                    441 non-null    object
#  3   _trusted_judgments             441 non-null    int64
#  4   _last_judgment_at              416 non-null    object
#  5   birthplace                     441 non-null    object
#  6   birthplace:confidence          441 non-null    float64
#  7   date_of_birth                  441 non-null    object
#  8   date_of_birth:confidence       441 non-null    float64
#  9   race_ethnicity                 441 non-null    object
#  10  race_ethnicity:confidence      441 non-null    float64
#  11  religion                       441 non-null    object
#  12  religion:confidence            441 non-null    float64
#  13  sexual_orientation             441 non-null    object
#  14  sexual_orientation:confidence  441 non-null    float64
#  15  year_of_award                  441 non-null    int64
#  16  year_of_award:confidence       441 non-null    float64
#  17  award                          441 non-null    object
#  18  biourl                         441 non-null    object
#  19  birthplace_gold                9 non-null      object
#  20  date_of_birth_gold             8 non-null      object
#  21  movie                          441 non-null    object
#  22  person                         441 non-null    object
#  23  race_ethnicity_gold            2 non-null      object
#  24  religion_gold                  10 non-null     object
#  25  sexual_orientation_gold        3 non-null      object
#  26  year_of_award_gold             11 non-null     float64
# dtypes: bool(1), float64(7), int64(3), object(16)
# memory usage: 90.1+ KB

# %%
# Some stats about the numeric columns in our dataset
oscars_demographics.describe()
# Out:
#            _unit_id  _trusted_judgments  birthplace:confidence  \
# count  4.410000e+02          441.000000             441.000000
# mean   6.704825e+08            7.637188               0.995259
# std    1.139974e+05           19.015541               0.038917
# min    6.704544e+08            3.000000               0.657100
# 25%    6.704545e+08            3.000000               1.000000
# 50%    6.704546e+08            3.000000               1.000000
# 75%    6.704547e+08            3.000000               1.000000
# max    6.709729e+08           95.000000               1.000000
#
#        date_of_birth:confidence  race_ethnicity:confidence  \
# count                441.000000                 441.000000
# mean                   0.996607                   0.999130
# std                    0.032060                   0.016438
# min                    0.656200                   0.657100
# 25%                    1.000000                   1.000000
# 50%                    1.000000                   1.000000
# 75%                    1.000000                   1.000000
# max                    1.000000                   1.000000
#
#        religion:confidence  sexual_orientation:confidence  year_of_award  \
# count           441.000000                     441.000000     441.000000
# mean              0.989373                       0.992390    1973.165533
# std               0.065610                       0.049458      24.030895
# min               0.333300                       0.657100    1927.000000
# 25%               1.000000                       1.000000    1953.000000
# 50%               1.000000                       1.000000    1973.000000
# 75%               1.000000                       1.000000    1994.000000
# max               1.000000                       1.000000    2014.000000
#
#        year_of_award:confidence  year_of_award_gold
# count                441.000000           11.000000
# mean                   0.990082         1977.363636
# std                    0.059177           21.592928
# min                    0.333300         1942.000000
# 25%                    1.000000         1964.000000
# 50%                    1.000000         1977.000000
# 75%                    1.000000         1997.000000
# max                    1.000000         2006.000000

# %% [markdown]
# ### DataFrame structure
#
# #### This is how a DataFrame is shown. We can see that both the column names and the index names are in bold. Columns and index provide labels to the columns and rows, which allow for direct and easy access to different subsets of data.
#
# #### DataFrame data (values) is always in regular font and is an entirely separate component from the columns or index.
#
# ####  Each of the three DataFrame components: the index, columns, and data; may be accessed directly from a DataFrame. Each of these components is itself a Python object with its own unique attributes and methods.
#
# #### Let´s see how to access each of them:
# ####

# %%
oscars_index = oscars_demographics.index
oscars_columns = oscars_demographics.columns
oscars_data = oscars_demographics.values

# %%
oscars_index
# Out:
# RangeIndex(start=0, stop=441, step=1)

# %%
oscars_columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'birthplace', 'birthplace:confidence',
#        'date_of_birth', 'date_of_birth:confidence', 'race_ethnicity',
#        'race_ethnicity:confidence', 'religion', 'religion:confidence',
#        'sexual_orientation', 'sexual_orientation:confidence', 'year_of_award',
#        'year_of_award:confidence', 'award', 'biourl', 'birthplace_gold',
#        'date_of_birth_gold', 'movie', 'person', 'race_ethnicity_gold',
#        'religion_gold', 'sexual_orientation_gold', 'year_of_award_gold'],
#       dtype='object')

# %%
oscars_data
# Out:
# array([[670454353, False, 'finalized', ..., nan, nan, nan],
#        [670454354, False, 'finalized', ..., nan, nan, nan],
#        [670454355, False, 'finalized', ..., nan, nan, nan],
#        ...,
#        [670964912, False, 'finalized', ..., nan, nan, nan],
#        [670964956, False, 'finalized', ..., nan, nan, nan],
#        [670972898, False, 'finalized', ..., nan, nan, nan]], dtype=object)

# %%
type(oscars_index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(oscars_columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(oscars_data)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Data Types
#
# * _bool_: Boolean, stored in a single byte
# * _int_: Integer, defaulted to 64bits, also available unsigned int
# * _float_: Float, defaulted to 64bits
# * _complex_: Complex, rarely seen in data analysis
# * _object_: Object, typically a string, but is a catch-all for columns with multiple different types or other python objects
# * _datetime64_: Datetime, specific moment in time
# * _timedelta64_: Timedelta, amount of time
# * _category_: Categorical, used for columns with a few possible values
#
# #### We can use _dtype_ to display the data type associated with each column
# ##

# %%
oscars_demographics.dtypes
# Out:
# _unit_id                           int64
# _golden                             bool
# _unit_state                       object
# _trusted_judgments                 int64
# _last_judgment_at                 object
# birthplace                        object
# birthplace:confidence            float64
# date_of_birth                     object
# date_of_birth:confidence         float64
# race_ethnicity                    object
# race_ethnicity:confidence        float64
# religion                          object
# religion:confidence              float64
# sexual_orientation                object
# sexual_orientation:confidence    float64
# year_of_award                      int64
# year_of_award:confidence         float64
# award                             object
# biourl                            object
# birthplace_gold                   object
# date_of_birth_gold                object
# movie                             object
# person                            object
# race_ethnicity_gold               object
# religion_gold                     object
# sexual_orientation_gold           object
# year_of_award_gold               float64
# dtype: object

# %%
#Using dtypes we saw the data types of each column. To see the quantity of columns with each data type we can use value_counts:
oscars_demographics.dtypes.value_counts()
# Out:
# object     16
# float64     7
# int64       3
# bool        1
# dtype: int64

# %% [markdown]
# ### Series
#
#   It is a __single dimension__ of data, composed of just an index and the data
#
#   We can select a column using the __index operator__, or using the __dot notation__.
#
# ###

# %%
# We can indicate a column name, using the index operator:

oscars_demographics['person']
# Out:
# 0      Lewis Milestone
# 1          Frank Lloyd
# 2      Lewis Milestone
# 3        Norman Taurog
# 4        Frank Borzage
#             ...
# 436       Rachel Weisz
# 437        Danny Boyle
# 438      Jason Robards
# 439       James Coburn
# 440        John Huston
# Name: person, Length: 441, dtype: object

# %%
# We can also use the dot notation to indicate which column to select

oscars_demographics.person
# Out:
# 0      Lewis Milestone
# 1          Frank Lloyd
# 2      Lewis Milestone
# 3        Norman Taurog
# 4        Frank Borzage
#             ...
# 436       Rachel Weisz
# 437        Danny Boyle
# 438      Jason Robards
# 439       James Coburn
# 440        John Huston
# Name: person, Length: 441, dtype: object

# %% [markdown]
# ### In this case, both outputs are the same, they are series. It has an index and data, the data type is the one from the column, in this case is object.
#
# Notice that this worked because the column name doesn´t include a blank. If the column was named business name instead of name, it whouldn´t have worked.
#
# Best practice is to use always the __index operator__, and avoid the use of the dot notation.
# ###

# %%
#To verify the data type of the output:

type(oscars_demographics['person'])
# Out:
# pandas.core.series.Series

# %%
type(oscars_demographics['person'].to_frame())
# Out:
# pandas.core.frame.DataFrame

# %%
oscars_demographics['person'].to_frame().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   person  441 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB

# %% [markdown]
# ### Series Methods
#
# #### We will start understanding what methods can be applied to a series, and some examples. Methods will depend on the data type.
# ###

# %%
s_attr_methods = set(dir(pd.Series))
len(s_attr_methods)
# Out:
# 434

# %%
s_attr_methods
# Out:
# {'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_binop',
#  '_box_item_values',
#  '_builtin_table',
#  '_can_hold_na',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_convert_dtypes',
#  '_create_indexer',
#  '_cython_table',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_type',
#  '_find_valid_index',
#  '_from_axes',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_cython_func',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values',
#  '_get_values_tuple',
#  '_get_with',
#  '_gotitem',
#  '_iget_item_cache',
#  '_index',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_dict',
#  '_init_mgr',
#  '_internal_get_values',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_copy',
#  '_is_datelike_mixed_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_map_values',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_ndarray_values',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_indexer',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_data_resource_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_set_labels',
#  '_set_name',
#  '_set_subtyp',
#  '_set_value',
#  '_set_values',
#  '_set_with',
#  '_set_with_engine',
#  '_setup_axes',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_unpickle_series_compat',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'array',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'autocorr',
#  'axes',
#  'between',
#  'between_time',
#  'bfill',
#  'bool',
#  'cat',
#  'clip',
#  'combine',
#  'combine_first',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'divmod',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dt',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'ewm',
#  'expanding',
#  'explode',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'interpolate',
#  'is_monotonic',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_unique',
#  'isin',
#  'isna',
#  'isnull',
#  'item',
#  'items',
#  'iteritems',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lt',
#  'mad',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'memory_usage',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'name',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'rdivmod',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'searchsorted',
#  'sem',
#  'set_axis',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'sparse',
#  'squeeze',
#  'std',
#  'str',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_latex',
#  'to_list',
#  'to_markdown',
#  'to_numpy',
#  'to_period',
#  'to_pickle',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'tolist',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs'}

# %%
df_attr_methods = set(dir(pd.DataFrame))
len(df_attr_methods)
# Out:
# 431

# %%
df_attr_methods
# Out:
# {'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_box_col_values',
#  '_box_item_values',
#  '_builtin_table',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_combine_frame',
#  '_combine_match_index',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_create_indexer',
#  '_cython_table',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_type',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_from_arrays',
#  '_from_axes',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_cython_func',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_iget_item_cache',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_internal_get_values',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_copy',
#  '_is_datelike_mixed_type',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_join_compat',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_series',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_setup_axes',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'sparse',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'values',
#  'var',
#  'where',
#  'xs'}

# %% [markdown]
# #### As an example, we will select columns with two different data types

# %%
#Selecting two columns with different data types:
oscars_movie = oscars_demographics['movie']
oscars_year = oscars_demographics['year_of_award']

# %%
oscars_movie.head()
# Out:
# 0               Two Arabian Knights
# 1                   The Divine Lady
# 2    All Quiet on the Western Front
# 3                            Skippy
# 4                          Bad Girl
# Name: movie, dtype: object

# %%
oscars_year.head()
# Out:
# 0    1927
# 1    1930
# 2    1931
# 3    1932
# 4    1933
# Name: year_of_award, dtype: int64

# %% [markdown]
# ### Value_Counts()
#
# This method is usefull to understand the distribution the data on the serie contains. It´s usually more useful in object series than in numeric series

# %%
oscars_movie.value_counts()
# Out:
# Million Dollar Baby             5
# Network                         4
# West Side Story                 4
# A Streetcar Named Desire        3
# Mrs. Miniver                    3
#                                ..
# The Graduate                    1
# Scent of a Woman                1
# Guess Who's Coming to Dinner    1
# The Champ                       1
# A Place in the Sun              1
# Name: movie, Length: 336, dtype: int64

# %% [markdown]
# We can also see the values normalized, which give us another perspective on the volume of occurency of each of the elemnts:

# %%
oscars_movie.value_counts(normalize=True)
# Out:
# Million Dollar Baby             0.011338
# Network                         0.009070
# West Side Story                 0.009070
# A Streetcar Named Desire        0.006803
# Mrs. Miniver                    0.006803
#                                   ...
# The Graduate                    0.002268
# Scent of a Woman                0.002268
# Guess Who's Coming to Dinner    0.002268
# The Champ                       0.002268
# A Place in the Sun              0.002268
# Name: movie, Length: 336, dtype: float64

# %% [markdown]
# #### Although it is more useful in object series, it helps to understand values distribution in some numeric series:
# ####

# %%
oscars_year.value_counts()
# Out:
# 1969    8
# 2005    7
# 1961    7
# 1999    7
# 2009    7
#        ..
# 1932    3
# 1931    3
# 1929    2
# 1933    1
# 1927    1
# Name: year_of_award, Length: 87, dtype: int64

# %%
oscars_demographics['year_of_award'].value_counts()
# Out:
# 1969    8
# 2005    7
# 1961    7
# 1999    7
# 2009    7
#        ..
# 1932    3
# 1931    3
# 1929    2
# 1933    1
# 1927    1
# Name: year_of_award, Length: 87, dtype: int64

# %% [markdown]
# #### Value_counts() return a series, where the value is the index, and the count associated to the value is the element.

# %% [markdown]
# #### Counting the number of elements in a serie: size, shape, len()

# %%
oscars_demographics.size
# Out:
# 11907

# %%
oscars_demographics.shape
# Out:
# (441, 27)

# %%
len(oscars_demographics)
# Out:
# 441

# %%
oscars_demographics.count()
# Out:
# _unit_id                         441
# _golden                          441
# _unit_state                      441
# _trusted_judgments               441
# _last_judgment_at                416
# birthplace                       441
# birthplace:confidence            441
# date_of_birth                    441
# date_of_birth:confidence         441
# race_ethnicity                   441
# race_ethnicity:confidence        441
# religion                         441
# religion:confidence              441
# sexual_orientation               441
# sexual_orientation:confidence    441
# year_of_award                    441
# year_of_award:confidence         441
# award                            441
# biourl                           441
# birthplace_gold                    9
# date_of_birth_gold                 8
# movie                            441
# person                           441
# race_ethnicity_gold                2
# religion_gold                     10
# sexual_orientation_gold            3
# year_of_award_gold                11
# dtype: int64

# %% [markdown]
# _size_, _len_ and _count_ return __scala__ values, but _shape_ returns a __one-item tuple__.

# %% [markdown]
# #### Difference between size, shape, len() and Count()

# %%
# Although size (shape and len) will still give us the number of elements:
oscars_demographics['date_of_birth_gold'].size
# Out:
# 441

# %%
# Count will give us the number of elements with values:
oscars_demographics['date_of_birth_gold'].count()
# Out:
# 8

# %%
# Because of this result, we know there are null values. To confirm this we can run isnull() which will return a serie of the same length as the original one, indicating True (if null) or false (if not)
oscars_demographics['date_of_birth_gold'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 436    True
# 437    True
# 438    True
# 439    True
# 440    True
# Name: date_of_birth_gold, Length: 441, dtype: bool

# %%
# We can also check if there are null values by using hasnans attribute:
oscars_demographics['date_of_birth_gold'].hasnans
# Out:
# True

# %%
# We need to take a decision on what to do with te null values. Sometimes we can ignore them, sometimes we can eliminate them, and others we can fill them using a specific value, or the previous or following value in the serie.

oscars_demographics.count()
# Out:
# _unit_id                         441
# _golden                          441
# _unit_state                      441
# _trusted_judgments               441
# _last_judgment_at                416
# birthplace                       441
# birthplace:confidence            441
# date_of_birth                    441
# date_of_birth:confidence         441
# race_ethnicity                   441
# race_ethnicity:confidence        441
# religion                         441
# religion:confidence              441
# sexual_orientation               441
# sexual_orientation:confidence    441
# year_of_award                    441
# year_of_award:confidence         441
# award                            441
# biourl                           441
# birthplace_gold                    9
# date_of_birth_gold                 8
# movie                            441
# person                           441
# race_ethnicity_gold                2
# religion_gold                     10
# sexual_orientation_gold            3
# year_of_award_gold                11
# dtype: int64

# %%
oscars_date_of_birth_gold = oscars_demographics['date_of_birth_gold']
oscars_date_of_birth_gold
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 436    NaN
# 437    NaN
# 438    NaN
# 439    NaN
# 440    NaN
# Name: date_of_birth_gold, Length: 441, dtype: object

# %%
# Filling Nan with a specific value:

oscars_date_of_birth_gold_fillna = oscars_date_of_birth_gold.fillna('None')

# %%
oscars_date_of_birth_gold_fillna.count()
# Out:
# 441

# %%
oscars_date_of_birth_gold_fillna.size
# Out:
# 441

# %%
# removing NaN elements:

oscars_date_of_birth_gold_dropped = oscars_date_of_birth_gold.dropna()

# %%
oscars_date_of_birth_gold_dropped.count()
# Out:
# 8

# %%
oscars_date_of_birth_gold_dropped.size
# Out:
# 8

# %% [markdown]
# #### Basic Statistics: min, max, mean, median, std, sum and describe methods

# %%
oscars_demographics._trusted_judgments.min(),oscars_demographics._trusted_judgments.max(),oscars_demographics._trusted_judgments.mean(),oscars_demographics._trusted_judgments.median(),oscars_demographics._trusted_judgments.std(),oscars_demographics._trusted_judgments.sum()
# Out:
# (3, 95, 7.63718820861678, 3.0, 19.015540899806783, 3368)

# %%
oscars_demographics._trusted_judgments.describe()
# Out:
# count    441.000000
# mean       7.637188
# std       19.015541
# min        3.000000
# 25%        3.000000
# 50%        3.000000
# 75%        3.000000
# max       95.000000
# Name: _trusted_judgments, dtype: float64

# %%
oscars_demographics.movie.describe()
# Out:
# count                     441
# unique                    336
# top       Million Dollar Baby
# freq                        5
# Name: movie, dtype: object

# %%
oscars_demographics.describe()
# Out:
#            _unit_id  _trusted_judgments  birthplace:confidence  \
# count  4.410000e+02          441.000000             441.000000
# mean   6.704825e+08            7.637188               0.995259
# std    1.139974e+05           19.015541               0.038917
# min    6.704544e+08            3.000000               0.657100
# 25%    6.704545e+08            3.000000               1.000000
# 50%    6.704546e+08            3.000000               1.000000
# 75%    6.704547e+08            3.000000               1.000000
# max    6.709729e+08           95.000000               1.000000
#
#        date_of_birth:confidence  race_ethnicity:confidence  \
# count                441.000000                 441.000000
# mean                   0.996607                   0.999130
# std                    0.032060                   0.016438
# min                    0.656200                   0.657100
# 25%                    1.000000                   1.000000
# 50%                    1.000000                   1.000000
# 75%                    1.000000                   1.000000
# max                    1.000000                   1.000000
#
#        religion:confidence  sexual_orientation:confidence  year_of_award  \
# count           441.000000                     441.000000     441.000000
# mean              0.989373                       0.992390    1973.165533
# std               0.065610                       0.049458      24.030895
# min               0.333300                       0.657100    1927.000000
# 25%               1.000000                       1.000000    1953.000000
# 50%               1.000000                       1.000000    1973.000000
# 75%               1.000000                       1.000000    1994.000000
# max               1.000000                       1.000000    2014.000000
#
#        year_of_award:confidence  year_of_award_gold
# count                441.000000           11.000000
# mean                   0.990082         1977.363636
# std                    0.059177           21.592928
# min                    0.333300         1942.000000
# 25%                    1.000000         1964.000000
# 50%                    1.000000         1977.000000
# 75%                    1.000000         1997.000000
# max                    1.000000         2006.000000

# %% [markdown]
# ### Operators on a Series

# %%
oscars_demographics['_trusted_judgments']
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 436    3
# 437    3
# 438    3
# 439    3
# 440    3
# Name: _trusted_judgments, Length: 441, dtype: int64

# %%
oscars_demographics['_trusted_judgments'].mean()
# Out:
# 7.63718820861678

# %%
oscars_demographics['_trusted_judgments'].min()
# Out:
# 3

# %%
oscars_demographics['_trusted_judgments'].max()
# Out:
# 95

# %%
oscars_demographics['_trusted_judgments'].value_counts()
# Out:
# 3     416
# 91      5
# 87      3
# 86      3
# 84      2
# 76      2
# 75      2
# 95      1
# 92      1
# 90      1
# 89      1
# 85      1
# 82      1
# 81      1
# 62      1
# Name: _trusted_judgments, dtype: int64

# %%
oscars_demographics['_trusted_judgments'].min()+1
# Out:
# 4

# %%
mas_uno=oscars_demographics['_trusted_judgments']+1

# %%
mas_uno.head()
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# Name: _trusted_judgments, dtype: int64

# %%
mas_uno.min()
# Out:
# 4

# %%
mas_uno.max()
# Out:
# 96

# %%
oscars_demographics['_trusted_judgments'] * 3
# Out:
# 0      9
# 1      9
# 2      9
# 3      9
# 4      9
#       ..
# 436    9
# 437    9
# 438    9
# 439    9
# 440    9
# Name: _trusted_judgments, Length: 441, dtype: int64

# %% [markdown]
# If we multiply a series it will return another series, with that operation applied to each of the elemnts. We can also use other operators as sum (+), minus (-), division (//), and exponentiation (**). Note that consecutive division operators (//) is used for floor division and the percent sign (%) for the modulus operator, which returns the remainder after a division.
#
# We can also use comparison opperators, like __greater than__ (>), __less than__ (<), __greater than or equal to__ (>=), __less than or equal to__ (<=), __equal to__ (==), and __not equal to__ (!=). These also return a seris, where each elemen is True or False based on the result of the comparison.

# %%
(oscars_year==1969).value_counts()
# Out:
# False    433
# True       8
# Name: year_of_award, dtype: int64

# %% [markdown]
# #### For every operator, there is also a method that does the same thing:
#
# #### Arithmetic
#
# * instead of +, -, *, /, //, %, **   We can use: add, sub, mul, div, floordiv, mod, pow
#
# #### Comparison
#
# * Instead of <, >, <=, >=, ==, !=  We can use:  lt, gt, le, ge, eq, ne

# %%
oscars_year.eq(1969).value_counts()
# Out:
# False    433
# True       8
# Name: year_of_award, dtype: int64

# %% [markdown]
# ### Chaining Series Methods Together
#
# #### As methods usually return other series or dataframes, it is possible to concatenate two or more methods.
#
# * We use dot (.) to concatenate methods
# * We use back-slash (\\) to continue the sentence in the following line
# * To facilitate reading, we try to use only one method per line
# * We can also use parentheses to indicate the whole sentense

# %% [markdown]
# Let´s say we want to count the NaN values on Year of Award gold, we can do it using isnll() and sum() methods:

# %%
oscars_demographics['year_of_award_gold'].isnull().sum()
# Out:
# 430

# %% [markdown]
# Or the average of NaN with mean()

# %%
oscars_demographics['year_of_award_gold'].isnull().mean()
# Out:
# 0.9750566893424036

# %% [markdown]
# To split the line in two different lines, we can use \

# %%
oscars_demographics['year_of_award_gold'].isnull()\
    .mean()
# Out:
# 0.9750566893424036

# %% [markdown]
# Or writing the sentence between ()

# %%
(oscars_demographics['year_of_award_gold'].isnull()
     .mean())
# Out:
# 0.9750566893424036

# %% [markdown]
# ## Cleaning the Dataset
# In this section we are going to clean the Data and get ir ready for all the analysis.
# The steps we are going to take are:
#
# * Keep the columns we are interested in using
# * Clean Null values from the dataset, we just remove the whole movie if it has a null value in a column.
# * Convert year to INT (from float)

# %%
# Keep only interesting columns
oscars = oscars_demographics[['birthplace',
       'date_of_birth', 'race_ethnicity', 'religion',
       'sexual_orientation', 'year_of_award', 'award', 'movie', 'person']]

# %%
# Clean NAs
print(len(oscars))
oscars.dropna(inplace=True)
print(len(oscars))
# Out:
# 441
# 441
# /home/matias/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
oscars.tail()
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 436      London, England      7-Mar-71          White          Jewish
# 437  Manchester, England     20-Oct-56          White  Roman Catholic
# 438          Chicago, Il     26-Jul-22          White              Na
# 439           Laurel, Ne     31-Aug-28          White              Na
# 440           Nevada, Mo      5-Aug-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
# 438           Straight           1977    Best Supporting Actor
# 439           Straight           1999    Best Supporting Actor
# 440           Straight           1949            Best Director
#
#                                 movie         person
# 436             The Constant Gardener   Rachel Weisz
# 437               Slumdog Millionaire    Danny Boyle
# 438           All the President's Men  Jason Robards
# 439                        Affliction   James Coburn
# 440  The Treasure of the Sierra Madre    John Huston

# %%
oscars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   birthplace          441 non-null    object
#  1   date_of_birth       441 non-null    object
#  2   race_ethnicity      441 non-null    object
#  3   religion            441 non-null    object
#  4   sexual_orientation  441 non-null    object
#  5   year_of_award       441 non-null    int64
#  6   award               441 non-null    object
#  7   movie               441 non-null    object
#  8   person              441 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 34.5+ KB

# %% [markdown]
# ### Indexes
#
# * Indexes provide a label for each row
# * If no index is explicitly provided, a RangeIndex is created with labels starting in 0
# ####

# %% [markdown]
# If we go back to our example, business did have a __RangeIndex__:

# %%
oscars
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova   30-Sep-1895          White              Na
# 1      Glasgow, Scotland    2-Feb-1886          White              Na
# 2      Chisinau, Moldova   30-Sep-1895          White              Na
# 3            Chicago, Il   23-Feb-1899          White              Na
# 4     Salt Lake City, Ut   23-Apr-1894          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 436      London, England      7-Mar-71          White          Jewish
# 437  Manchester, England     20-Oct-56          White  Roman Catholic
# 438          Chicago, Il     26-Jul-22          White              Na
# 439           Laurel, Ne     31-Aug-28          White              Na
# 440           Nevada, Mo      5-Aug-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
# 438           Straight           1977    Best Supporting Actor
# 439           Straight           1999    Best Supporting Actor
# 440           Straight           1949            Best Director
#
#                                 movie           person
# 0                 Two Arabian Knights  Lewis Milestone
# 1                     The Divine Lady      Frank Lloyd
# 2      All Quiet on the Western Front  Lewis Milestone
# 3                              Skippy    Norman Taurog
# 4                            Bad Girl    Frank Borzage
# ..                                ...              ...
# 436             The Constant Gardener     Rachel Weisz
# 437               Slumdog Millionaire      Danny Boyle
# 438           All the President's Men    Jason Robards
# 439                        Affliction     James Coburn
# 440  The Treasure of the Sierra Madre      John Huston
#
# [441 rows x 9 columns]

# %% [markdown]
# We can change the index and use business Id instead, using the set_index method:

# %%
oscars.count()
# Out:
# birthplace            441
# date_of_birth         441
# race_ethnicity        441
# religion              441
# sexual_orientation    441
# year_of_award         441
# award                 441
# movie                 441
# person                441
# dtype: int64

# %%
oscars_byID=oscars.set_index(['person','year_of_award'])

# %%
oscars_byID
# Out:
#                                         birthplace date_of_birth  \
# person          year_of_award
# Lewis Milestone 1927             Chisinau, Moldova   30-Sep-1895
# Frank Lloyd     1930             Glasgow, Scotland    2-Feb-1886
# Lewis Milestone 1931             Chisinau, Moldova   30-Sep-1895
# Norman Taurog   1932                   Chicago, Il   23-Feb-1899
# Frank Borzage   1933            Salt Lake City, Ut   23-Apr-1894
# ...                                            ...           ...
# Rachel Weisz    2006               London, England      7-Mar-71
# Danny Boyle     2009           Manchester, England     20-Oct-56
# Jason Robards   1977                   Chicago, Il     26-Jul-22
# James Coburn    1999                    Laurel, Ne     31-Aug-28
# John Huston     1949                    Nevada, Mo      5-Aug-06
#
#                               race_ethnicity        religion  \
# person          year_of_award
# Lewis Milestone 1927                   White              Na
# Frank Lloyd     1930                   White              Na
# Lewis Milestone 1931                   White              Na
# Norman Taurog   1932                   White              Na
# Frank Borzage   1933                   White  Roman Catholic
# ...                                      ...             ...
# Rachel Weisz    2006                   White          Jewish
# Danny Boyle     2009                   White  Roman Catholic
# Jason Robards   1977                   White              Na
# James Coburn    1999                   White              Na
# John Huston     1949                   White              Na
#
#                               sexual_orientation                    award  \
# person          year_of_award
# Lewis Milestone 1927                    Straight            Best Director
# Frank Lloyd     1930                    Straight            Best Director
# Lewis Milestone 1931                    Straight            Best Director
# Norman Taurog   1932                    Straight            Best Director
# Frank Borzage   1933                    Straight            Best Director
# ...                                          ...                      ...
# Rachel Weisz    2006                    Straight  Best Supporting Actress
# Danny Boyle     2009                    Straight            Best Director
# Jason Robards   1977                    Straight    Best Supporting Actor
# James Coburn    1999                    Straight    Best Supporting Actor
# John Huston     1949                    Straight            Best Director
#
#                                                           movie
# person          year_of_award
# Lewis Milestone 1927                        Two Arabian Knights
# Frank Lloyd     1930                            The Divine Lady
# Lewis Milestone 1931             All Quiet on the Western Front
# Norman Taurog   1932                                     Skippy
# Frank Borzage   1933                                   Bad Girl
# ...                                                         ...
# Rachel Weisz    2006                      The Constant Gardener
# Danny Boyle     2009                        Slumdog Millionaire
# Jason Robards   1977                    All the President's Men
# James Coburn    1999                                 Affliction
# John Huston     1949           The Treasure of the Sierra Madre
#
# [441 rows x 7 columns]

# %%
oscars_byID.count()
# Out:
# birthplace            441
# date_of_birth         441
# race_ethnicity        441
# religion              441
# sexual_orientation    441
# award                 441
# movie                 441
# dtype: int64

# %%
oscars_byID = pd.read_csv('Oscars-demographics-DFE.csv', encoding='latin-1', index_col=['person','year_of_award'])
oscars_byID.tail()
# Out:
#                               _unit_id  _golden _unit_state  \
# person        year_of_award
# Rachel Weisz  2006           670946276    False   finalized
# Danny Boyle   2009           670946299    False   finalized
# Jason Robards 1977           670964912    False   finalized
# James Coburn  1999           670964956    False   finalized
# John Huston   1949           670972898    False   finalized
#
#                              _trusted_judgments _last_judgment_at  \
# person        year_of_award
# Rachel Weisz  2006                            3      2/10/15 2:00
# Danny Boyle   2009                            3      2/10/15 2:04
# Jason Robards 1977                            3      2/10/15 2:03
# James Coburn  1999                            3      2/10/15 2:01
# John Huston   1949                            3      2/10/15 2:01
#
#                                       birthplace  birthplace:confidence  \
# person        year_of_award
# Rachel Weisz  2006               London, England                    1.0
# Danny Boyle   2009           Manchester, England                    1.0
# Jason Robards 1977                   Chicago, Il                    1.0
# James Coburn  1999                    Laurel, Ne                    1.0
# John Huston   1949                    Nevada, Mo                    1.0
#
#                             date_of_birth  date_of_birth:confidence  \
# person        year_of_award
# Rachel Weisz  2006               7-Mar-71                       1.0
# Danny Boyle   2009              20-Oct-56                       1.0
# Jason Robards 1977              26-Jul-22                       1.0
# James Coburn  1999              31-Aug-28                       1.0
# John Huston   1949               5-Aug-06                       1.0
#
#                             race_ethnicity  ...  year_of_award:confidence  \
# person        year_of_award                 ...
# Rachel Weisz  2006                   White  ...                    0.6857
# Danny Boyle   2009                   White  ...                    1.0000
# Jason Robards 1977                   White  ...                    1.0000
# James Coburn  1999                   White  ...                    1.0000
# John Huston   1949                   White  ...                    1.0000
#
#                                                award  \
# person        year_of_award
# Rachel Weisz  2006           Best Supporting Actress
# Danny Boyle   2009                     Best Director
# Jason Robards 1977             Best Supporting Actor
# James Coburn  1999             Best Supporting Actor
# John Huston   1949                     Best Director
#
#                                                                 biourl  \
# person        year_of_award
# Rachel Weisz  2006           http://www.nndb.com/people/309/000032213/
# Danny Boyle   2009           http://www.nndb.com/people/887/000044755/
# Jason Robards 1977           http://www.nndb.com/people/224/000032128/
# James Coburn  1999           http://www.nndb.com/people/764/000022698/
# John Huston   1949           http://www.nndb.com/people/704/000024632/
#
#                             birthplace_gold  date_of_birth_gold  \
# person        year_of_award
# Rachel Weisz  2006                      NaN                 NaN
# Danny Boyle   2009                      NaN                 NaN
# Jason Robards 1977                      NaN                 NaN
# James Coburn  1999                      NaN                 NaN
# John Huston   1949                      NaN                 NaN
#
#                                                         movie  \
# person        year_of_award
# Rachel Weisz  2006                      The Constant Gardener
# Danny Boyle   2009                        Slumdog Millionaire
# Jason Robards 1977                    All the President's Men
# James Coburn  1999                                 Affliction
# John Huston   1949           The Treasure of the Sierra Madre
#
#                             race_ethnicity_gold religion_gold  \
# person        year_of_award
# Rachel Weisz  2006                          NaN           NaN
# Danny Boyle   2009                          NaN           NaN
# Jason Robards 1977                          NaN           NaN
# James Coburn  1999                          NaN           NaN
# John Huston   1949                          NaN           NaN
#
#                             sexual_orientation_gold year_of_award_gold
# person        year_of_award
# Rachel Weisz  2006                              NaN                NaN
# Danny Boyle   2009                              NaN                NaN
# Jason Robards 1977                              NaN                NaN
# James Coburn  1999                              NaN                NaN
# John Huston   1949                              NaN                NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# We can eliminate the index using the reset_index method:

# %%
oscars_byID.reset_index()
# Out:
#               person  year_of_award   _unit_id  _golden _unit_state  \
# 0    Lewis Milestone           1927  670454353    False   finalized
# 1        Frank Lloyd           1930  670454354    False   finalized
# 2    Lewis Milestone           1931  670454355    False   finalized
# 3      Norman Taurog           1932  670454356    False   finalized
# 4      Frank Borzage           1933  670454357    False   finalized
# ..               ...            ...        ...      ...         ...
# 436     Rachel Weisz           2006  670946276    False   finalized
# 437      Danny Boyle           2009  670946299    False   finalized
# 438    Jason Robards           1977  670964912    False   finalized
# 439     James Coburn           1999  670964956    False   finalized
# 440      John Huston           1949  670972898    False   finalized
#
#      _trusted_judgments _last_judgment_at           birthplace  \
# 0                     3      2/10/15 3:45    Chisinau, Moldova
# 1                     3      2/10/15 2:03    Glasgow, Scotland
# 2                     3      2/10/15 2:05    Chisinau, Moldova
# 3                     3      2/10/15 2:04          Chicago, Il
# 4                     3      2/10/15 1:48   Salt Lake City, Ut
# ..                  ...               ...                  ...
# 436                   3      2/10/15 2:00      London, England
# 437                   3      2/10/15 2:04  Manchester, England
# 438                   3      2/10/15 2:03          Chicago, Il
# 439                   3      2/10/15 2:01           Laurel, Ne
# 440                   3      2/10/15 2:01           Nevada, Mo
#
#      birthplace:confidence date_of_birth  ...  year_of_award:confidence  \
# 0                      1.0   30-Sep-1895  ...                    1.0000
# 1                      1.0    2-Feb-1886  ...                    1.0000
# 2                      1.0   30-Sep-1895  ...                    0.6667
# 3                      1.0   23-Feb-1899  ...                    1.0000
# 4                      1.0   23-Apr-1894  ...                    1.0000
# ..                     ...           ...  ...                       ...
# 436                    1.0      7-Mar-71  ...                    0.6857
# 437                    1.0     20-Oct-56  ...                    1.0000
# 438                    1.0     26-Jul-22  ...                    1.0000
# 439                    1.0     31-Aug-28  ...                    1.0000
# 440                    1.0      5-Aug-06  ...                    1.0000
#
#                        award                                     biourl  \
# 0              Best Director  http://www.nndb.com/people/320/000043191/
# 1              Best Director  http://www.nndb.com/people/626/000042500/
# 2              Best Director  http://www.nndb.com/people/320/000043191/
# 3              Best Director  http://www.nndb.com/people/544/000041421/
# 4              Best Director  http://www.nndb.com/people/292/000044160/
# ..                       ...                                        ...
# 436  Best Supporting Actress  http://www.nndb.com/people/309/000032213/
# 437            Best Director  http://www.nndb.com/people/887/000044755/
# 438    Best Supporting Actor  http://www.nndb.com/people/224/000032128/
# 439    Best Supporting Actor  http://www.nndb.com/people/764/000022698/
# 440            Best Director  http://www.nndb.com/people/704/000024632/
#
#     birthplace_gold  date_of_birth_gold                             movie  \
# 0               NaN                 NaN               Two Arabian Knights
# 1               NaN                 NaN                   The Divine Lady
# 2               NaN                 NaN    All Quiet on the Western Front
# 3               NaN                 NaN                            Skippy
# 4               NaN                 NaN                          Bad Girl
# ..              ...                 ...                               ...
# 436             NaN                 NaN             The Constant Gardener
# 437             NaN                 NaN               Slumdog Millionaire
# 438             NaN                 NaN           All the President's Men
# 439             NaN                 NaN                        Affliction
# 440             NaN                 NaN  The Treasure of the Sierra Madre
#
#      race_ethnicity_gold  religion_gold sexual_orientation_gold  \
# 0                    NaN            NaN                     NaN
# 1                    NaN            NaN                     NaN
# 2                    NaN            NaN                     NaN
# 3                    NaN            NaN                     NaN
# 4                    NaN            NaN                     NaN
# ..                   ...            ...                     ...
# 436                  NaN            NaN                     NaN
# 437                  NaN            NaN                     NaN
# 438                  NaN            NaN                     NaN
# 439                  NaN            NaN                     NaN
# 440                  NaN            NaN                     NaN
#
#     year_of_award_gold
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 436                NaN
# 437                NaN
# 438                NaN
# 439                NaN
# 440                NaN
#
# [441 rows x 27 columns]

# %% [markdown]
# #### In both cases we can see that business_id is set as the DataFrame index, and there is no business_id column. If we want to still have a business_id column we can use set_index with the parameter drop = False

# %%
oscars_byID=oscars.set_index(['person','year_of_award'],drop=False)

# %%
oscars_byID
# Out:
#                                         birthplace date_of_birth  \
# person          year_of_award
# Lewis Milestone 1927             Chisinau, Moldova   30-Sep-1895
# Frank Lloyd     1930             Glasgow, Scotland    2-Feb-1886
# Lewis Milestone 1931             Chisinau, Moldova   30-Sep-1895
# Norman Taurog   1932                   Chicago, Il   23-Feb-1899
# Frank Borzage   1933            Salt Lake City, Ut   23-Apr-1894
# ...                                            ...           ...
# Rachel Weisz    2006               London, England      7-Mar-71
# Danny Boyle     2009           Manchester, England     20-Oct-56
# Jason Robards   1977                   Chicago, Il     26-Jul-22
# James Coburn    1999                    Laurel, Ne     31-Aug-28
# John Huston     1949                    Nevada, Mo      5-Aug-06
#
#                               race_ethnicity        religion  \
# person          year_of_award
# Lewis Milestone 1927                   White              Na
# Frank Lloyd     1930                   White              Na
# Lewis Milestone 1931                   White              Na
# Norman Taurog   1932                   White              Na
# Frank Borzage   1933                   White  Roman Catholic
# ...                                      ...             ...
# Rachel Weisz    2006                   White          Jewish
# Danny Boyle     2009                   White  Roman Catholic
# Jason Robards   1977                   White              Na
# James Coburn    1999                   White              Na
# John Huston     1949                   White              Na
#
#                               sexual_orientation  year_of_award  \
# person          year_of_award
# Lewis Milestone 1927                    Straight           1927
# Frank Lloyd     1930                    Straight           1930
# Lewis Milestone 1931                    Straight           1931
# Norman Taurog   1932                    Straight           1932
# Frank Borzage   1933                    Straight           1933
# ...                                          ...            ...
# Rachel Weisz    2006                    Straight           2006
# Danny Boyle     2009                    Straight           2009
# Jason Robards   1977                    Straight           1977
# James Coburn    1999                    Straight           1999
# John Huston     1949                    Straight           1949
#
#                                                  award  \
# person          year_of_award
# Lewis Milestone 1927                     Best Director
# Frank Lloyd     1930                     Best Director
# Lewis Milestone 1931                     Best Director
# Norman Taurog   1932                     Best Director
# Frank Borzage   1933                     Best Director
# ...                                                ...
# Rachel Weisz    2006           Best Supporting Actress
# Danny Boyle     2009                     Best Director
# Jason Robards   1977             Best Supporting Actor
# James Coburn    1999             Best Supporting Actor
# John Huston     1949                     Best Director
#
#                                                           movie  \
# person          year_of_award
# Lewis Milestone 1927                        Two Arabian Knights
# Frank Lloyd     1930                            The Divine Lady
# Lewis Milestone 1931             All Quiet on the Western Front
# Norman Taurog   1932                                     Skippy
# Frank Borzage   1933                                   Bad Girl
# ...                                                         ...
# Rachel Weisz    2006                      The Constant Gardener
# Danny Boyle     2009                        Slumdog Millionaire
# Jason Robards   1977                    All the President's Men
# James Coburn    1999                                 Affliction
# John Huston     1949           The Treasure of the Sierra Madre
#
#                                         person
# person          year_of_award
# Lewis Milestone 1927           Lewis Milestone
# Frank Lloyd     1930               Frank Lloyd
# Lewis Milestone 1931           Lewis Milestone
# Norman Taurog   1932             Norman Taurog
# Frank Borzage   1933             Frank Borzage
# ...                                        ...
# Rachel Weisz    2006              Rachel Weisz
# Danny Boyle     2009               Danny Boyle
# Jason Robards   1977             Jason Robards
# James Coburn    1999              James Coburn
# John Huston     1949               John Huston
#
# [441 rows x 9 columns]

# %% [markdown]
# ### Renaming Row and Column Names
#
# * To make them more descriptive
# * To follow a standard
# * To avoid blanks, and other special characters

# %%
oscars_byID = pd.read_csv('Oscars-demographics-DFE.csv', encoding='latin-1', index_col=['person','year_of_award'])
oscars_byID.tail()
# Out:
#                               _unit_id  _golden _unit_state  \
# person        year_of_award
# Rachel Weisz  2006           670946276    False   finalized
# Danny Boyle   2009           670946299    False   finalized
# Jason Robards 1977           670964912    False   finalized
# James Coburn  1999           670964956    False   finalized
# John Huston   1949           670972898    False   finalized
#
#                              _trusted_judgments _last_judgment_at  \
# person        year_of_award
# Rachel Weisz  2006                            3      2/10/15 2:00
# Danny Boyle   2009                            3      2/10/15 2:04
# Jason Robards 1977                            3      2/10/15 2:03
# James Coburn  1999                            3      2/10/15 2:01
# John Huston   1949                            3      2/10/15 2:01
#
#                                       birthplace  birthplace:confidence  \
# person        year_of_award
# Rachel Weisz  2006               London, England                    1.0
# Danny Boyle   2009           Manchester, England                    1.0
# Jason Robards 1977                   Chicago, Il                    1.0
# James Coburn  1999                    Laurel, Ne                    1.0
# John Huston   1949                    Nevada, Mo                    1.0
#
#                             date_of_birth  date_of_birth:confidence  \
# person        year_of_award
# Rachel Weisz  2006               7-Mar-71                       1.0
# Danny Boyle   2009              20-Oct-56                       1.0
# Jason Robards 1977              26-Jul-22                       1.0
# James Coburn  1999              31-Aug-28                       1.0
# John Huston   1949               5-Aug-06                       1.0
#
#                             race_ethnicity  ...  year_of_award:confidence  \
# person        year_of_award                 ...
# Rachel Weisz  2006                   White  ...                    0.6857
# Danny Boyle   2009                   White  ...                    1.0000
# Jason Robards 1977                   White  ...                    1.0000
# James Coburn  1999                   White  ...                    1.0000
# John Huston   1949                   White  ...                    1.0000
#
#                                                award  \
# person        year_of_award
# Rachel Weisz  2006           Best Supporting Actress
# Danny Boyle   2009                     Best Director
# Jason Robards 1977             Best Supporting Actor
# James Coburn  1999             Best Supporting Actor
# John Huston   1949                     Best Director
#
#                                                                 biourl  \
# person        year_of_award
# Rachel Weisz  2006           http://www.nndb.com/people/309/000032213/
# Danny Boyle   2009           http://www.nndb.com/people/887/000044755/
# Jason Robards 1977           http://www.nndb.com/people/224/000032128/
# James Coburn  1999           http://www.nndb.com/people/764/000022698/
# John Huston   1949           http://www.nndb.com/people/704/000024632/
#
#                             birthplace_gold  date_of_birth_gold  \
# person        year_of_award
# Rachel Weisz  2006                      NaN                 NaN
# Danny Boyle   2009                      NaN                 NaN
# Jason Robards 1977                      NaN                 NaN
# James Coburn  1999                      NaN                 NaN
# John Huston   1949                      NaN                 NaN
#
#                                                         movie  \
# person        year_of_award
# Rachel Weisz  2006                      The Constant Gardener
# Danny Boyle   2009                        Slumdog Millionaire
# Jason Robards 1977                    All the President's Men
# James Coburn  1999                                 Affliction
# John Huston   1949           The Treasure of the Sierra Madre
#
#                             race_ethnicity_gold religion_gold  \
# person        year_of_award
# Rachel Weisz  2006                          NaN           NaN
# Danny Boyle   2009                          NaN           NaN
# Jason Robards 1977                          NaN           NaN
# James Coburn  1999                          NaN           NaN
# John Huston   1949                          NaN           NaN
#
#                             sexual_orientation_gold year_of_award_gold
# person        year_of_award
# Rachel Weisz  2006                              NaN                NaN
# Danny Boyle   2009                              NaN                NaN
# Jason Robards 1977                              NaN                NaN
# James Coburn  1999                              NaN                NaN
# John Huston   1949                              NaN                NaN
#
# [5 rows x 25 columns]

# %%
idx_rename={'James Coburn':'Jimmy Coburn'}
col_rename={'unit_id':'Unit_ID','golden':'Golden'}
oscars_byID_renamed=oscars_byID.rename(index=idx_rename, columns=col_rename)
oscars_byID_renamed
# Out:
#                                 _unit_id  _golden _unit_state  \
# person          year_of_award
# Lewis Milestone 1927           670454353    False   finalized
# Frank Lloyd     1930           670454354    False   finalized
# Lewis Milestone 1931           670454355    False   finalized
# Norman Taurog   1932           670454356    False   finalized
# Frank Borzage   1933           670454357    False   finalized
# ...                                  ...      ...         ...
# Rachel Weisz    2006           670946276    False   finalized
# Danny Boyle     2009           670946299    False   finalized
# Jason Robards   1977           670964912    False   finalized
# Jimmy Coburn    1999           670964956    False   finalized
# John Huston     1949           670972898    False   finalized
#
#                                _trusted_judgments _last_judgment_at  \
# person          year_of_award
# Lewis Milestone 1927                            3      2/10/15 3:45
# Frank Lloyd     1930                            3      2/10/15 2:03
# Lewis Milestone 1931                            3      2/10/15 2:05
# Norman Taurog   1932                            3      2/10/15 2:04
# Frank Borzage   1933                            3      2/10/15 1:48
# ...                                           ...               ...
# Rachel Weisz    2006                            3      2/10/15 2:00
# Danny Boyle     2009                            3      2/10/15 2:04
# Jason Robards   1977                            3      2/10/15 2:03
# Jimmy Coburn    1999                            3      2/10/15 2:01
# John Huston     1949                            3      2/10/15 2:01
#
#                                         birthplace  birthplace:confidence  \
# person          year_of_award
# Lewis Milestone 1927             Chisinau, Moldova                    1.0
# Frank Lloyd     1930             Glasgow, Scotland                    1.0
# Lewis Milestone 1931             Chisinau, Moldova                    1.0
# Norman Taurog   1932                   Chicago, Il                    1.0
# Frank Borzage   1933            Salt Lake City, Ut                    1.0
# ...                                            ...                    ...
# Rachel Weisz    2006               London, England                    1.0
# Danny Boyle     2009           Manchester, England                    1.0
# Jason Robards   1977                   Chicago, Il                    1.0
# Jimmy Coburn    1999                    Laurel, Ne                    1.0
# John Huston     1949                    Nevada, Mo                    1.0
#
#                               date_of_birth  date_of_birth:confidence  \
# person          year_of_award
# Lewis Milestone 1927            30-Sep-1895                       1.0
# Frank Lloyd     1930             2-Feb-1886                       1.0
# Lewis Milestone 1931            30-Sep-1895                       1.0
# Norman Taurog   1932            23-Feb-1899                       1.0
# Frank Borzage   1933            23-Apr-1894                       1.0
# ...                                     ...                       ...
# Rachel Weisz    2006               7-Mar-71                       1.0
# Danny Boyle     2009              20-Oct-56                       1.0
# Jason Robards   1977              26-Jul-22                       1.0
# Jimmy Coburn    1999              31-Aug-28                       1.0
# John Huston     1949               5-Aug-06                       1.0
#
#                               race_ethnicity  ...  year_of_award:confidence  \
# person          year_of_award                 ...
# Lewis Milestone 1927                   White  ...                    1.0000
# Frank Lloyd     1930                   White  ...                    1.0000
# Lewis Milestone 1931                   White  ...                    0.6667
# Norman Taurog   1932                   White  ...                    1.0000
# Frank Borzage   1933                   White  ...                    1.0000
# ...                                      ...  ...                       ...
# Rachel Weisz    2006                   White  ...                    0.6857
# Danny Boyle     2009                   White  ...                    1.0000
# Jason Robards   1977                   White  ...                    1.0000
# Jimmy Coburn    1999                   White  ...                    1.0000
# John Huston     1949                   White  ...                    1.0000
#
#                                                  award  \
# person          year_of_award
# Lewis Milestone 1927                     Best Director
# Frank Lloyd     1930                     Best Director
# Lewis Milestone 1931                     Best Director
# Norman Taurog   1932                     Best Director
# Frank Borzage   1933                     Best Director
# ...                                                ...
# Rachel Weisz    2006           Best Supporting Actress
# Danny Boyle     2009                     Best Director
# Jason Robards   1977             Best Supporting Actor
# Jimmy Coburn    1999             Best Supporting Actor
# John Huston     1949                     Best Director
#
#                                                                   biourl  \
# person          year_of_award
# Lewis Milestone 1927           http://www.nndb.com/people/320/000043191/
# Frank Lloyd     1930           http://www.nndb.com/people/626/000042500/
# Lewis Milestone 1931           http://www.nndb.com/people/320/000043191/
# Norman Taurog   1932           http://www.nndb.com/people/544/000041421/
# Frank Borzage   1933           http://www.nndb.com/people/292/000044160/
# ...                                                                  ...
# Rachel Weisz    2006           http://www.nndb.com/people/309/000032213/
# Danny Boyle     2009           http://www.nndb.com/people/887/000044755/
# Jason Robards   1977           http://www.nndb.com/people/224/000032128/
# Jimmy Coburn    1999           http://www.nndb.com/people/764/000022698/
# John Huston     1949           http://www.nndb.com/people/704/000024632/
#
#                               birthplace_gold  date_of_birth_gold  \
# person          year_of_award
# Lewis Milestone 1927                      NaN                 NaN
# Frank Lloyd     1930                      NaN                 NaN
# Lewis Milestone 1931                      NaN                 NaN
# Norman Taurog   1932                      NaN                 NaN
# Frank Borzage   1933                      NaN                 NaN
# ...                                       ...                 ...
# Rachel Weisz    2006                      NaN                 NaN
# Danny Boyle     2009                      NaN                 NaN
# Jason Robards   1977                      NaN                 NaN
# Jimmy Coburn    1999                      NaN                 NaN
# John Huston     1949                      NaN                 NaN
#
#                                                           movie  \
# person          year_of_award
# Lewis Milestone 1927                        Two Arabian Knights
# Frank Lloyd     1930                            The Divine Lady
# Lewis Milestone 1931             All Quiet on the Western Front
# Norman Taurog   1932                                     Skippy
# Frank Borzage   1933                                   Bad Girl
# ...                                                         ...
# Rachel Weisz    2006                      The Constant Gardener
# Danny Boyle     2009                        Slumdog Millionaire
# Jason Robards   1977                    All the President's Men
# Jimmy Coburn    1999                                 Affliction
# John Huston     1949           The Treasure of the Sierra Madre
#
#                               race_ethnicity_gold religion_gold  \
# person          year_of_award
# Lewis Milestone 1927                          NaN           NaN
# Frank Lloyd     1930                          NaN           NaN
# Lewis Milestone 1931                          NaN           NaN
# Norman Taurog   1932                          NaN           NaN
# Frank Borzage   1933                          NaN           NaN
# ...                                           ...           ...
# Rachel Weisz    2006                          NaN           NaN
# Danny Boyle     2009                          NaN           NaN
# Jason Robards   1977                          NaN           NaN
# Jimmy Coburn    1999                          NaN           NaN
# John Huston     1949                          NaN           NaN
#
#                               sexual_orientation_gold year_of_award_gold
# person          year_of_award
# Lewis Milestone 1927                              NaN                NaN
# Frank Lloyd     1930                              NaN                NaN
# Lewis Milestone 1931                              NaN                NaN
# Norman Taurog   1932                              NaN                NaN
# Frank Borzage   1933                              NaN                NaN
# ...                                               ...                ...
# Rachel Weisz    2006                              NaN                NaN
# Danny Boyle     2009                              NaN                NaN
# Jason Robards   1977                              NaN                NaN
# Jimmy Coburn    1999                              NaN                NaN
# John Huston     1949                              NaN                NaN
#
# [441 rows x 25 columns]

# %%
oscars_byID.loc[('James Coburn',1999),:]
# Out:
# /home/matias/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1761: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)
#                              _unit_id  _golden _unit_state  \
# person       year_of_award
# James Coburn 1999           670454588     True      golden
#              1999           670964956    False   finalized
#
#                             _trusted_judgments _last_judgment_at  birthplace  \
# person       year_of_award
# James Coburn 1999                           62               NaN  Laurel, Ne
#              1999                            3      2/10/15 2:01  Laurel, Ne
#
#                             birthplace:confidence date_of_birth  \
# person       year_of_award
# James Coburn 1999                             1.0     31-Aug-28
#              1999                             1.0     31-Aug-28
#
#                             date_of_birth:confidence race_ethnicity  ...  \
# person       year_of_award                                           ...
# James Coburn 1999                                1.0          White  ...
#              1999                                1.0          White  ...
#
#                             year_of_award:confidence                  award  \
# person       year_of_award
# James Coburn 1999                                1.0  Best Supporting Actor
#              1999                                1.0  Best Supporting Actor
#
#                                                                biourl  \
# person       year_of_award
# James Coburn 1999           http://www.nndb.com/people/764/000022698/
#              1999           http://www.nndb.com/people/764/000022698/
#
#                            birthplace_gold  date_of_birth_gold       movie  \
# person       year_of_award
# James Coburn 1999                      NaN                 NaN  Affliction
#              1999                      NaN                 NaN  Affliction
#
#                            race_ethnicity_gold religion_gold  \
# person       year_of_award
# James Coburn 1999                          NaN            Na
#              1999                          NaN           NaN
#
#                            sexual_orientation_gold year_of_award_gold
# person       year_of_award
# James Coburn 1999                              NaN                NaN
#              1999                              NaN                NaN
#
# [2 rows x 25 columns]

# %%
# We can obtain index and column from business dataframe:
oscars_columns=oscars_byID.columns
oscars_columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'birthplace', 'birthplace:confidence',
#        'date_of_birth', 'date_of_birth:confidence', 'race_ethnicity',
#        'race_ethnicity:confidence', 'religion', 'religion:confidence',
#        'sexual_orientation', 'sexual_orientation:confidence',
#        'year_of_award:confidence', 'award', 'biourl', 'birthplace_gold',
#        'date_of_birth_gold', 'movie', 'race_ethnicity_gold', 'religion_gold',
#        'sexual_orientation_gold', 'year_of_award_gold'],
#       dtype='object')

# %%
columns_list=oscars_columns.tolist()
columns_list
# Out:
# ['_unit_id',
#  '_golden',
#  '_unit_state',
#  '_trusted_judgments',
#  '_last_judgment_at',
#  'birthplace',
#  'birthplace:confidence',
#  'date_of_birth',
#  'date_of_birth:confidence',
#  'race_ethnicity',
#  'race_ethnicity:confidence',
#  'religion',
#  'religion:confidence',
#  'sexual_orientation',
#  'sexual_orientation:confidence',
#  'year_of_award:confidence',
#  'award',
#  'biourl',
#  'birthplace_gold',
#  'date_of_birth_gold',
#  'movie',
#  'race_ethnicity_gold',
#  'religion_gold',
#  'sexual_orientation_gold',
#  'year_of_award_gold']

# %%
# Rename one or more elements of the lists
columns_list[0]='unitID'
# And finally we assign it back to the Data Frame
oscars_byID.columns=columns_list
oscars_byID
# Out:
#                                   unitID  _golden _unit_state  \
# person          year_of_award
# Lewis Milestone 1927           670454353    False   finalized
# Frank Lloyd     1930           670454354    False   finalized
# Lewis Milestone 1931           670454355    False   finalized
# Norman Taurog   1932           670454356    False   finalized
# Frank Borzage   1933           670454357    False   finalized
# ...                                  ...      ...         ...
# Rachel Weisz    2006           670946276    False   finalized
# Danny Boyle     2009           670946299    False   finalized
# Jason Robards   1977           670964912    False   finalized
# James Coburn    1999           670964956    False   finalized
# John Huston     1949           670972898    False   finalized
#
#                                _trusted_judgments _last_judgment_at  \
# person          year_of_award
# Lewis Milestone 1927                            3      2/10/15 3:45
# Frank Lloyd     1930                            3      2/10/15 2:03
# Lewis Milestone 1931                            3      2/10/15 2:05
# Norman Taurog   1932                            3      2/10/15 2:04
# Frank Borzage   1933                            3      2/10/15 1:48
# ...                                           ...               ...
# Rachel Weisz    2006                            3      2/10/15 2:00
# Danny Boyle     2009                            3      2/10/15 2:04
# Jason Robards   1977                            3      2/10/15 2:03
# James Coburn    1999                            3      2/10/15 2:01
# John Huston     1949                            3      2/10/15 2:01
#
#                                         birthplace  birthplace:confidence  \
# person          year_of_award
# Lewis Milestone 1927             Chisinau, Moldova                    1.0
# Frank Lloyd     1930             Glasgow, Scotland                    1.0
# Lewis Milestone 1931             Chisinau, Moldova                    1.0
# Norman Taurog   1932                   Chicago, Il                    1.0
# Frank Borzage   1933            Salt Lake City, Ut                    1.0
# ...                                            ...                    ...
# Rachel Weisz    2006               London, England                    1.0
# Danny Boyle     2009           Manchester, England                    1.0
# Jason Robards   1977                   Chicago, Il                    1.0
# James Coburn    1999                    Laurel, Ne                    1.0
# John Huston     1949                    Nevada, Mo                    1.0
#
#                               date_of_birth  date_of_birth:confidence  \
# person          year_of_award
# Lewis Milestone 1927            30-Sep-1895                       1.0
# Frank Lloyd     1930             2-Feb-1886                       1.0
# Lewis Milestone 1931            30-Sep-1895                       1.0
# Norman Taurog   1932            23-Feb-1899                       1.0
# Frank Borzage   1933            23-Apr-1894                       1.0
# ...                                     ...                       ...
# Rachel Weisz    2006               7-Mar-71                       1.0
# Danny Boyle     2009              20-Oct-56                       1.0
# Jason Robards   1977              26-Jul-22                       1.0
# James Coburn    1999              31-Aug-28                       1.0
# John Huston     1949               5-Aug-06                       1.0
#
#                               race_ethnicity  ...  year_of_award:confidence  \
# person          year_of_award                 ...
# Lewis Milestone 1927                   White  ...                    1.0000
# Frank Lloyd     1930                   White  ...                    1.0000
# Lewis Milestone 1931                   White  ...                    0.6667
# Norman Taurog   1932                   White  ...                    1.0000
# Frank Borzage   1933                   White  ...                    1.0000
# ...                                      ...  ...                       ...
# Rachel Weisz    2006                   White  ...                    0.6857
# Danny Boyle     2009                   White  ...                    1.0000
# Jason Robards   1977                   White  ...                    1.0000
# James Coburn    1999                   White  ...                    1.0000
# John Huston     1949                   White  ...                    1.0000
#
#                                                  award  \
# person          year_of_award
# Lewis Milestone 1927                     Best Director
# Frank Lloyd     1930                     Best Director
# Lewis Milestone 1931                     Best Director
# Norman Taurog   1932                     Best Director
# Frank Borzage   1933                     Best Director
# ...                                                ...
# Rachel Weisz    2006           Best Supporting Actress
# Danny Boyle     2009                     Best Director
# Jason Robards   1977             Best Supporting Actor
# James Coburn    1999             Best Supporting Actor
# John Huston     1949                     Best Director
#
#                                                                   biourl  \
# person          year_of_award
# Lewis Milestone 1927           http://www.nndb.com/people/320/000043191/
# Frank Lloyd     1930           http://www.nndb.com/people/626/000042500/
# Lewis Milestone 1931           http://www.nndb.com/people/320/000043191/
# Norman Taurog   1932           http://www.nndb.com/people/544/000041421/
# Frank Borzage   1933           http://www.nndb.com/people/292/000044160/
# ...                                                                  ...
# Rachel Weisz    2006           http://www.nndb.com/people/309/000032213/
# Danny Boyle     2009           http://www.nndb.com/people/887/000044755/
# Jason Robards   1977           http://www.nndb.com/people/224/000032128/
# James Coburn    1999           http://www.nndb.com/people/764/000022698/
# John Huston     1949           http://www.nndb.com/people/704/000024632/
#
#                               birthplace_gold  date_of_birth_gold  \
# person          year_of_award
# Lewis Milestone 1927                      NaN                 NaN
# Frank Lloyd     1930                      NaN                 NaN
# Lewis Milestone 1931                      NaN                 NaN
# Norman Taurog   1932                      NaN                 NaN
# Frank Borzage   1933                      NaN                 NaN
# ...                                       ...                 ...
# Rachel Weisz    2006                      NaN                 NaN
# Danny Boyle     2009                      NaN                 NaN
# Jason Robards   1977                      NaN                 NaN
# James Coburn    1999                      NaN                 NaN
# John Huston     1949                      NaN                 NaN
#
#                                                           movie  \
# person          year_of_award
# Lewis Milestone 1927                        Two Arabian Knights
# Frank Lloyd     1930                            The Divine Lady
# Lewis Milestone 1931             All Quiet on the Western Front
# Norman Taurog   1932                                     Skippy
# Frank Borzage   1933                                   Bad Girl
# ...                                                         ...
# Rachel Weisz    2006                      The Constant Gardener
# Danny Boyle     2009                        Slumdog Millionaire
# Jason Robards   1977                    All the President's Men
# James Coburn    1999                                 Affliction
# John Huston     1949           The Treasure of the Sierra Madre
#
#                               race_ethnicity_gold religion_gold  \
# person          year_of_award
# Lewis Milestone 1927                          NaN           NaN
# Frank Lloyd     1930                          NaN           NaN
# Lewis Milestone 1931                          NaN           NaN
# Norman Taurog   1932                          NaN           NaN
# Frank Borzage   1933                          NaN           NaN
# ...                                           ...           ...
# Rachel Weisz    2006                          NaN           NaN
# Danny Boyle     2009                          NaN           NaN
# Jason Robards   1977                          NaN           NaN
# James Coburn    1999                          NaN           NaN
# John Huston     1949                          NaN           NaN
#
#                               sexual_orientation_gold year_of_award_gold
# person          year_of_award
# Lewis Milestone 1927                              NaN                NaN
# Frank Lloyd     1930                              NaN                NaN
# Lewis Milestone 1931                              NaN                NaN
# Norman Taurog   1932                              NaN                NaN
# Frank Borzage   1933                              NaN                NaN
# ...                                               ...                ...
# Rachel Weisz    2006                              NaN                NaN
# Danny Boyle     2009                              NaN                NaN
# Jason Robards   1977                              NaN                NaN
# James Coburn    1999                              NaN                NaN
# John Huston     1949                              NaN                NaN
#
# [441 rows x 25 columns]

# %%
oscars
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova   30-Sep-1895          White              Na
# 1      Glasgow, Scotland    2-Feb-1886          White              Na
# 2      Chisinau, Moldova   30-Sep-1895          White              Na
# 3            Chicago, Il   23-Feb-1899          White              Na
# 4     Salt Lake City, Ut   23-Apr-1894          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 436      London, England      7-Mar-71          White          Jewish
# 437  Manchester, England     20-Oct-56          White  Roman Catholic
# 438          Chicago, Il     26-Jul-22          White              Na
# 439           Laurel, Ne     31-Aug-28          White              Na
# 440           Nevada, Mo      5-Aug-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
# 438           Straight           1977    Best Supporting Actor
# 439           Straight           1999    Best Supporting Actor
# 440           Straight           1949            Best Director
#
#                                 movie           person
# 0                 Two Arabian Knights  Lewis Milestone
# 1                     The Divine Lady      Frank Lloyd
# 2      All Quiet on the Western Front  Lewis Milestone
# 3                              Skippy    Norman Taurog
# 4                            Bad Girl    Frank Borzage
# ..                                ...              ...
# 436             The Constant Gardener     Rachel Weisz
# 437               Slumdog Millionaire      Danny Boyle
# 438           All the President's Men    Jason Robards
# 439                        Affliction     James Coburn
# 440  The Treasure of the Sierra Madre      John Huston
#
# [441 rows x 9 columns]

# %%
oscars.loc[0]
# Out:
# birthplace              Chisinau, Moldova
# date_of_birth                 30-Sep-1895
# race_ethnicity                      White
# religion                               Na
# sexual_orientation               Straight
# year_of_award                        1927
# award                       Best Director
# movie                 Two Arabian Knights
# person                    Lewis Milestone
# Name: 0, dtype: object

# %%
oscars_person=oscars[['person','date_of_birth','birthplace']].drop_duplicates(subset='person')
oscars_person.set_index('person',inplace=True)

# %%
oscars_person
# Out:
#                 date_of_birth                 birthplace
# person
# Lewis Milestone   30-Sep-1895          Chisinau, Moldova
# Frank Lloyd        2-Feb-1886          Glasgow, Scotland
# Norman Taurog     23-Feb-1899                Chicago, Il
# Frank Borzage     23-Apr-1894         Salt Lake City, Ut
# Frank Capra       18-May-1897  Bisacquino, Sicily, Italy
# ...                       ...                        ...
# Mo'Nique            11-Dec-67               Woodlawn, Md
# Melissa Leo         14-Sep-60              New York City
# Octavia Spencer     25-May-72             Montgomery, Al
# Anne Hathaway       12-Nov-82               Brooklyn, Ny
# Lupita Nyong'o       1-Mar-83        Mexico City, Mexico
#
# [348 rows x 2 columns]

# %%
oscars_awards=oscars[['person','year_of_award','award','movie']].drop_duplicates(subset='person')
oscars_awards.set_index('person',inplace=True)
oscars_awards
# Out:
#                  year_of_award                    award                  movie
# person
# Lewis Milestone           1927            Best Director    Two Arabian Knights
# Frank Lloyd               1930            Best Director        The Divine Lady
# Norman Taurog             1932            Best Director                 Skippy
# Frank Borzage             1933            Best Director               Bad Girl
# Frank Capra               1935            Best Director  It Happened One Night
# ...                        ...                      ...                    ...
# Mo'Nique                  2010  Best Supporting Actress               Precious
# Melissa Leo               2011  Best Supporting Actress            The Fighter
# Octavia Spencer           2012  Best Supporting Actress               The Help
# Anne Hathaway             2013  Best Supporting Actress        Les MisÌ©rables
# Lupita Nyong'o            2014  Best Supporting Actress       12 Years a Slave
#
# [348 rows x 3 columns]

# %%
oscars_awards.loc['Anne Hathaway',:]
# Out:
# year_of_award                       2013
# award            Best Supporting Actress
# movie                    Les MisÌ©rables
# Name: Anne Hathaway, dtype: object

# %%
oscars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 440
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   birthplace          441 non-null    object
#  1   date_of_birth       441 non-null    object
#  2   race_ethnicity      441 non-null    object
#  3   religion            441 non-null    object
#  4   sexual_orientation  441 non-null    object
#  5   year_of_award       441 non-null    int64
#  6   award               441 non-null    object
#  7   movie               441 non-null    object
#  8   person              441 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 54.5+ KB

# %%
oscars.loc[:,'date_of_birth'] = pd.to_datetime(oscars['date_of_birth'], errors='coerce')
# Out:
# /home/matias/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
oscars_demographics
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0    670454353    False   finalized                   3      2/10/15 3:45
# 1    670454354    False   finalized                   3      2/10/15 2:03
# 2    670454355    False   finalized                   3      2/10/15 2:05
# 3    670454356    False   finalized                   3      2/10/15 2:04
# 4    670454357    False   finalized                   3      2/10/15 1:48
# ..         ...      ...         ...                 ...               ...
# 436  670946276    False   finalized                   3      2/10/15 2:00
# 437  670946299    False   finalized                   3      2/10/15 2:04
# 438  670964912    False   finalized                   3      2/10/15 2:03
# 439  670964956    False   finalized                   3      2/10/15 2:01
# 440  670972898    False   finalized                   3      2/10/15 2:01
#
#               birthplace  birthplace:confidence date_of_birth  \
# 0      Chisinau, Moldova                    1.0   30-Sep-1895
# 1      Glasgow, Scotland                    1.0    2-Feb-1886
# 2      Chisinau, Moldova                    1.0   30-Sep-1895
# 3            Chicago, Il                    1.0   23-Feb-1899
# 4     Salt Lake City, Ut                    1.0   23-Apr-1894
# ..                   ...                    ...           ...
# 436      London, England                    1.0      7-Mar-71
# 437  Manchester, England                    1.0     20-Oct-56
# 438          Chicago, Il                    1.0     26-Jul-22
# 439           Laurel, Ne                    1.0     31-Aug-28
# 440           Nevada, Mo                    1.0      5-Aug-06
#
#      date_of_birth:confidence race_ethnicity  ...                    award  \
# 0                         1.0          White  ...            Best Director
# 1                         1.0          White  ...            Best Director
# 2                         1.0          White  ...            Best Director
# 3                         1.0          White  ...            Best Director
# 4                         1.0          White  ...            Best Director
# ..                        ...            ...  ...                      ...
# 436                       1.0          White  ...  Best Supporting Actress
# 437                       1.0          White  ...            Best Director
# 438                       1.0          White  ...    Best Supporting Actor
# 439                       1.0          White  ...    Best Supporting Actor
# 440                       1.0          White  ...            Best Director
#
#                                         biourl  birthplace_gold  \
# 0    http://www.nndb.com/people/320/000043191/              NaN
# 1    http://www.nndb.com/people/626/000042500/              NaN
# 2    http://www.nndb.com/people/320/000043191/              NaN
# 3    http://www.nndb.com/people/544/000041421/              NaN
# 4    http://www.nndb.com/people/292/000044160/              NaN
# ..                                         ...              ...
# 436  http://www.nndb.com/people/309/000032213/              NaN
# 437  http://www.nndb.com/people/887/000044755/              NaN
# 438  http://www.nndb.com/people/224/000032128/              NaN
# 439  http://www.nndb.com/people/764/000022698/              NaN
# 440  http://www.nndb.com/people/704/000024632/              NaN
#
#     date_of_birth_gold                             movie           person  \
# 0                  NaN               Two Arabian Knights  Lewis Milestone
# 1                  NaN                   The Divine Lady      Frank Lloyd
# 2                  NaN    All Quiet on the Western Front  Lewis Milestone
# 3                  NaN                            Skippy    Norman Taurog
# 4                  NaN                          Bad Girl    Frank Borzage
# ..                 ...                               ...              ...
# 436                NaN             The Constant Gardener     Rachel Weisz
# 437                NaN               Slumdog Millionaire      Danny Boyle
# 438                NaN           All the President's Men    Jason Robards
# 439                NaN                        Affliction     James Coburn
# 440                NaN  The Treasure of the Sierra Madre      John Huston
#
#      race_ethnicity_gold religion_gold sexual_orientation_gold  \
# 0                    NaN           NaN                     NaN
# 1                    NaN           NaN                     NaN
# 2                    NaN           NaN                     NaN
# 3                    NaN           NaN                     NaN
# 4                    NaN           NaN                     NaN
# ..                   ...           ...                     ...
# 436                  NaN           NaN                     NaN
# 437                  NaN           NaN                     NaN
# 438                  NaN           NaN                     NaN
# 439                  NaN           NaN                     NaN
# 440                  NaN           NaN                     NaN
#
#     year_of_award_gold
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 436                NaN
# 437                NaN
# 438                NaN
# 439                NaN
# 440                NaN
#
# [441 rows x 27 columns]

# %% [markdown]
# ### Creating and Deleting Columns in a DataFrame

# %%
# We can easily create a new column by assigning values to it:
oscars_short['last_ten_years']=0
oscars_short
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova   30-Sep-1895          White              Na
# 1      Glasgow, Scotland    2-Feb-1886          White              Na
# 2      Chisinau, Moldova   30-Sep-1895          White              Na
# 3            Chicago, Il   23-Feb-1899          White              Na
# 4     Salt Lake City, Ut   23-Apr-1894          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 436      London, England      7-Mar-71          White          Jewish
# 437  Manchester, England     20-Oct-56          White  Roman Catholic
# 438          Chicago, Il     26-Jul-22          White              Na
# 439           Laurel, Ne     31-Aug-28          White              Na
# 440           Nevada, Mo      5-Aug-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
# 438           Straight           1977    Best Supporting Actor
# 439           Straight           1999    Best Supporting Actor
# 440           Straight           1949            Best Director
#
#                                 movie           person  last_ten_years
# 0                 Two Arabian Knights  Lewis Milestone               0
# 1                     The Divine Lady      Frank Lloyd               0
# 2      All Quiet on the Western Front  Lewis Milestone               0
# 3                              Skippy    Norman Taurog               0
# 4                            Bad Girl    Frank Borzage               0
# ..                                ...              ...             ...
# 436             The Constant Gardener     Rachel Weisz               0
# 437               Slumdog Millionaire      Danny Boyle               0
# 438           All the President's Men    Jason Robards               0
# 439                        Affliction     James Coburn               0
# 440  The Treasure of the Sierra Madre      John Huston               0
#
# [441 rows x 10 columns]

# %%
oscars_short['last_ten_years']=oscars_short['year_of_award']>2009
oscars_short
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova   30-Sep-1895          White              Na
# 1      Glasgow, Scotland    2-Feb-1886          White              Na
# 2      Chisinau, Moldova   30-Sep-1895          White              Na
# 3            Chicago, Il   23-Feb-1899          White              Na
# 4     Salt Lake City, Ut   23-Apr-1894          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 436      London, England      7-Mar-71          White          Jewish
# 437  Manchester, England     20-Oct-56          White  Roman Catholic
# 438          Chicago, Il     26-Jul-22          White              Na
# 439           Laurel, Ne     31-Aug-28          White              Na
# 440           Nevada, Mo      5-Aug-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
# 438           Straight           1977    Best Supporting Actor
# 439           Straight           1999    Best Supporting Actor
# 440           Straight           1949            Best Director
#
#                                 movie           person  last_ten_years
# 0                 Two Arabian Knights  Lewis Milestone           False
# 1                     The Divine Lady      Frank Lloyd           False
# 2      All Quiet on the Western Front  Lewis Milestone           False
# 3                              Skippy    Norman Taurog           False
# 4                            Bad Girl    Frank Borzage           False
# ..                                ...              ...             ...
# 436             The Constant Gardener     Rachel Weisz           False
# 437               Slumdog Millionaire      Danny Boyle           False
# 438           All the President's Men    Jason Robards           False
# 439                        Affliction     James Coburn           False
# 440  The Treasure of the Sierra Madre      John Huston           False
#
# [441 rows x 10 columns]

# %%
oscars_short['last_ten_years'].value_counts()
# Out:
# False    417
# True      24
# Name: last_ten_years, dtype: int64

# %%
#If we want to delete the column we just created:
oscars_short.drop(columns='last_ten_years',inplace=True)
oscars_short
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova   30-Sep-1895          White              Na
# 1      Glasgow, Scotland    2-Feb-1886          White              Na
# 2      Chisinau, Moldova   30-Sep-1895          White              Na
# 3            Chicago, Il   23-Feb-1899          White              Na
# 4     Salt Lake City, Ut   23-Apr-1894          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 436      London, England      7-Mar-71          White          Jewish
# 437  Manchester, England     20-Oct-56          White  Roman Catholic
# 438          Chicago, Il     26-Jul-22          White              Na
# 439           Laurel, Ne     31-Aug-28          White              Na
# 440           Nevada, Mo      5-Aug-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
# 438           Straight           1977    Best Supporting Actor
# 439           Straight           1999    Best Supporting Actor
# 440           Straight           1949            Best Director
#
#                                 movie           person
# 0                 Two Arabian Knights  Lewis Milestone
# 1                     The Divine Lady      Frank Lloyd
# 2      All Quiet on the Western Front  Lewis Milestone
# 3                              Skippy    Norman Taurog
# 4                            Bad Girl    Frank Borzage
# ..                                ...              ...
# 436             The Constant Gardener     Rachel Weisz
# 437               Slumdog Millionaire      Danny Boyle
# 438           All the President's Men    Jason Robards
# 439                        Affliction     James Coburn
# 440  The Treasure of the Sierra Madre      John Huston
#
# [441 rows x 9 columns]

# %% [markdown]
# If we want to add a column, but in a specific possition, we need to indicate that possition.
# Let´s add the column before the review_count. To do that we calculate the possition of the review_count and calulate it +1

# %%
date_of_birth_position=oscars_short.columns.get_loc('date_of_birth')+1
date_of_birth_position
# Out:
# 2

# %%
oscars_short.insert(loc=date_of_birth_position, column='last_ten_years', value=(oscars_short['year_of_award']>2009))
oscars_short
# Out:
#               birthplace date_of_birth  last_ten_years race_ethnicity  \
# 0      Chisinau, Moldova   30-Sep-1895           False          White
# 1      Glasgow, Scotland    2-Feb-1886           False          White
# 2      Chisinau, Moldova   30-Sep-1895           False          White
# 3            Chicago, Il   23-Feb-1899           False          White
# 4     Salt Lake City, Ut   23-Apr-1894           False          White
# ..                   ...           ...             ...            ...
# 436      London, England      7-Mar-71           False          White
# 437  Manchester, England     20-Oct-56           False          White
# 438          Chicago, Il     26-Jul-22           False          White
# 439           Laurel, Ne     31-Aug-28           False          White
# 440           Nevada, Mo      5-Aug-06           False          White
#
#            religion sexual_orientation  year_of_award  \
# 0                Na           Straight           1927
# 1                Na           Straight           1930
# 2                Na           Straight           1931
# 3                Na           Straight           1932
# 4    Roman Catholic           Straight           1933
# ..              ...                ...            ...
# 436          Jewish           Straight           2006
# 437  Roman Catholic           Straight           2009
# 438              Na           Straight           1977
# 439              Na           Straight           1999
# 440              Na           Straight           1949
#
#                        award                             movie  \
# 0              Best Director               Two Arabian Knights
# 1              Best Director                   The Divine Lady
# 2              Best Director    All Quiet on the Western Front
# 3              Best Director                            Skippy
# 4              Best Director                          Bad Girl
# ..                       ...                               ...
# 436  Best Supporting Actress             The Constant Gardener
# 437            Best Director               Slumdog Millionaire
# 438    Best Supporting Actor           All the President's Men
# 439    Best Supporting Actor                        Affliction
# 440            Best Director  The Treasure of the Sierra Madre
#
#               person
# 0    Lewis Milestone
# 1        Frank Lloyd
# 2    Lewis Milestone
# 3      Norman Taurog
# 4      Frank Borzage
# ..               ...
# 436     Rachel Weisz
# 437      Danny Boyle
# 438    Jason Robards
# 439     James Coburn
# 440      John Huston
#
# [441 rows x 10 columns]

# %%
del oscars_short['last_ten_years']
oscars_short
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova   30-Sep-1895          White              Na
# 1      Glasgow, Scotland    2-Feb-1886          White              Na
# 2      Chisinau, Moldova   30-Sep-1895          White              Na
# 3            Chicago, Il   23-Feb-1899          White              Na
# 4     Salt Lake City, Ut   23-Apr-1894          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 436      London, England      7-Mar-71          White          Jewish
# 437  Manchester, England     20-Oct-56          White  Roman Catholic
# 438          Chicago, Il     26-Jul-22          White              Na
# 439           Laurel, Ne     31-Aug-28          White              Na
# 440           Nevada, Mo      5-Aug-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
# 438           Straight           1977    Best Supporting Actor
# 439           Straight           1999    Best Supporting Actor
# 440           Straight           1949            Best Director
#
#                                 movie           person
# 0                 Two Arabian Knights  Lewis Milestone
# 1                     The Divine Lady      Frank Lloyd
# 2      All Quiet on the Western Front  Lewis Milestone
# 3                              Skippy    Norman Taurog
# 4                            Bad Girl    Frank Borzage
# ..                                ...              ...
# 436             The Constant Gardener     Rachel Weisz
# 437               Slumdog Millionaire      Danny Boyle
# 438           All the President's Men    Jason Robards
# 439                        Affliction     James Coburn
# 440  The Treasure of the Sierra Madre      John Huston
#
# [441 rows x 9 columns]

# %% [markdown]
# #
# ### Data Frame Operations
#
# #### We will now review other methods that apply to Data Frames, how to select multiple rows, how to chain multiple methods, etc

# %%
# Similar to what we did when selecting one column, but instead of providing a column name, we will be passing a list of columns:
oscars_basics = oscars_short[['person','movie','award','year_of_award']]
oscars_basics
# Out:
#               person                             movie  \
# 0    Lewis Milestone               Two Arabian Knights
# 1        Frank Lloyd                   The Divine Lady
# 2    Lewis Milestone    All Quiet on the Western Front
# 3      Norman Taurog                            Skippy
# 4      Frank Borzage                          Bad Girl
# ..               ...                               ...
# 436     Rachel Weisz             The Constant Gardener
# 437      Danny Boyle               Slumdog Millionaire
# 438    Jason Robards           All the President's Men
# 439     James Coburn                        Affliction
# 440      John Huston  The Treasure of the Sierra Madre
#
#                        award  year_of_award
# 0              Best Director           1927
# 1              Best Director           1930
# 2              Best Director           1931
# 3              Best Director           1932
# 4              Best Director           1933
# ..                       ...            ...
# 436  Best Supporting Actress           2006
# 437            Best Director           2009
# 438    Best Supporting Actor           1977
# 439    Best Supporting Actor           1999
# 440            Best Director           1949
#
# [441 rows x 4 columns]

# %% [markdown]
# #### Selecting columns with methods

# %%
oscars_short.dtypes.value_counts()
# Out:
# object    8
# int64     1
# dtype: int64

# %%
oscars_short.loc[:,'date_of_birth'] = pd.to_datetime(oscars_short['date_of_birth'], errors='coerce')

# %%
oscars_short.dtypes.value_counts()
# Out:
# object            7
# datetime64[ns]    1
# int64             1
# dtype: int64

# %% [markdown]
# We can select colums with a specific data type using the select_dtypes method.
# using the parameter include we can indicate the data type we are looking for:

# %%
oscars_short.select_dtypes(include=['int64']).head()
# Out:
#    year_of_award
# 0           1927
# 1           1930
# 2           1931
# 3           1932
# 4           1933

# %% [markdown]
# We can also select all numeric columns using include='number':

# %%
oscars_short.select_dtypes(include='number').head()
# Out:
#    year_of_award
# 0           1927
# 1           1930
# 2           1931
# 3           1932
# 4           1933

# %% [markdown]
# We can select specific columns by filtering contect on the column names.

# %%
oscars_short.filter(like='birth').head()
# Out:
#            birthplace date_of_birth
# 0   Chisinau, Moldova    1895-09-30
# 1   Glasgow, Scotland    1886-02-02
# 2   Chisinau, Moldova    1895-09-30
# 3         Chicago, Il    1899-02-23
# 4  Salt Lake City, Ut    1894-04-23

# %% [markdown]
# Filter also allows regular expressions:

# %%
oscars_short.filter(regex='\_').head()
# Out:
#   date_of_birth race_ethnicity sexual_orientation  year_of_award
# 0    1895-09-30          White           Straight           1927
# 1    1886-02-02          White           Straight           1930
# 2    1895-09-30          White           Straight           1931
# 3    1899-02-23          White           Straight           1932
# 4    1894-04-23          White           Straight           1933

# %% [markdown]
# Lastly, using items parameter we can indicate the list of columns to select:

# %%
oscars_short.filter(items=['person']).head()
# Out:
#             person
# 0  Lewis Milestone
# 1      Frank Lloyd
# 2  Lewis Milestone
# 3    Norman Taurog
# 4    Frank Borzage

# %% [markdown]
# ### Ordering Columns

# %%
oscars_short.columns
# Out:
# Index(['birthplace', 'date_of_birth', 'race_ethnicity', 'religion',
#        'sexual_orientation', 'year_of_award', 'award', 'movie', 'person'],
#       dtype='object')

# %% [markdown]
# Let´s imagine we want to have the name of the person at the beginning...

# %%
new_col_order = ['person', 'birthplace', 'date_of_birth', 'race_ethnicity', 'religion','sexual_orientation', 'year_of_award', 'award', 'movie']

oscars_new_col_order = oscars_short[new_col_order]
oscars_new_col_order.head()
# Out:
#             person          birthplace date_of_birth race_ethnicity  \
# 0  Lewis Milestone   Chisinau, Moldova    1895-09-30          White
# 1      Frank Lloyd   Glasgow, Scotland    1886-02-02          White
# 2  Lewis Milestone   Chisinau, Moldova    1895-09-30          White
# 3    Norman Taurog         Chicago, Il    1899-02-23          White
# 4    Frank Borzage  Salt Lake City, Ut    1894-04-23          White
#
#          religion sexual_orientation  year_of_award          award  \
# 0              Na           Straight           1927  Best Director
# 1              Na           Straight           1930  Best Director
# 2              Na           Straight           1931  Best Director
# 3              Na           Straight           1932  Best Director
# 4  Roman Catholic           Straight           1933  Best Director
#
#                             movie
# 0             Two Arabian Knights
# 1                 The Divine Lady
# 2  All Quiet on the Western Front
# 3                          Skippy
# 4                        Bad Girl

# %% [markdown]
# #
# ## Selecting subsets of data
#
# * Selecting Series data
# * Selecting DataFrame rows
# * Selecting DataFrame rows and columns simultaneously
# * Selecting data with both integers and labels
# * Speeding up scalar selection
# * Slicing rows lazily
# * Slicing lexicographically

# %%
oscars_short.head(10)
# Out:
#                   birthplace date_of_birth race_ethnicity        religion  \
# 0          Chisinau, Moldova    1895-09-30          White              Na
# 1          Glasgow, Scotland    1886-02-02          White              Na
# 2          Chisinau, Moldova    1895-09-30          White              Na
# 3                Chicago, Il    1899-02-23          White              Na
# 4         Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# 5          Glasgow, Scotland    1886-02-02          White              Na
# 6  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
# 7         Cape Elizabeth, Me    1894-02-01          White  Roman Catholic
# 8  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
# 9            Los Angeles, Ca    1898-10-03          White              Na
#
#   sexual_orientation  year_of_award          award  \
# 0           Straight           1927  Best Director
# 1           Straight           1930  Best Director
# 2           Straight           1931  Best Director
# 3           Straight           1932  Best Director
# 4           Straight           1933  Best Director
# 5           Straight           1934  Best Director
# 6           Straight           1935  Best Director
# 7           Bisexual           1936  Best Director
# 8           Straight           1937  Best Director
# 9           Straight           1938  Best Director
#
#                             movie           person
# 0             Two Arabian Knights  Lewis Milestone
# 1                 The Divine Lady      Frank Lloyd
# 2  All Quiet on the Western Front  Lewis Milestone
# 3                          Skippy    Norman Taurog
# 4                        Bad Girl    Frank Borzage
# 5                       Cavalcade      Frank Lloyd
# 6           It Happened One Night      Frank Capra
# 7                    The Informer        John Ford
# 8          Mr. Deeds Goes to Town      Frank Capra
# 9                 The Awful Truth      Leo McCarey

# %%
oscars_short.iloc[5]
# Out:
# birthplace              Glasgow, Scotland
# date_of_birth         1886-02-02 00:00:00
# race_ethnicity                      White
# religion                               Na
# sexual_orientation               Straight
# year_of_award                        1934
# award                       Best Director
# movie                           Cavalcade
# person                        Frank Lloyd
# Name: 5, dtype: object

# %%
oscars_short.iloc[0:6]
# Out:
#            birthplace date_of_birth race_ethnicity        religion  \
# 0   Chisinau, Moldova    1895-09-30          White              Na
# 1   Glasgow, Scotland    1886-02-02          White              Na
# 2   Chisinau, Moldova    1895-09-30          White              Na
# 3         Chicago, Il    1899-02-23          White              Na
# 4  Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# 5   Glasgow, Scotland    1886-02-02          White              Na
#
#   sexual_orientation  year_of_award          award  \
# 0           Straight           1927  Best Director
# 1           Straight           1930  Best Director
# 2           Straight           1931  Best Director
# 3           Straight           1932  Best Director
# 4           Straight           1933  Best Director
# 5           Straight           1934  Best Director
#
#                             movie           person
# 0             Two Arabian Knights  Lewis Milestone
# 1                 The Divine Lady      Frank Lloyd
# 2  All Quiet on the Western Front  Lewis Milestone
# 3                          Skippy    Norman Taurog
# 4                        Bad Girl    Frank Borzage
# 5                       Cavalcade      Frank Lloyd

# %%
oscars_short.iloc[5:10]
# Out:
#                   birthplace date_of_birth race_ethnicity        religion  \
# 5          Glasgow, Scotland    1886-02-02          White              Na
# 6  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
# 7         Cape Elizabeth, Me    1894-02-01          White  Roman Catholic
# 8  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
# 9            Los Angeles, Ca    1898-10-03          White              Na
#
#   sexual_orientation  year_of_award          award                   movie  \
# 5           Straight           1934  Best Director               Cavalcade
# 6           Straight           1935  Best Director   It Happened One Night
# 7           Bisexual           1936  Best Director            The Informer
# 8           Straight           1937  Best Director  Mr. Deeds Goes to Town
# 9           Straight           1938  Best Director         The Awful Truth
#
#         person
# 5  Frank Lloyd
# 6  Frank Capra
# 7    John Ford
# 8  Frank Capra
# 9  Leo McCarey

# %%
oscars_short.iloc[10:20:2]
# Out:
#                              birthplace date_of_birth race_ethnicity  \
# 10            Bisacquino, Sicily, Italy    1897-05-18          White
# 12                   Cape Elizabeth, Me    1894-02-01          White
# 14  Mulhouse, Haut-Rhin, Alsace, France    1902-07-01          White
# 16                      Los Angeles, Ca    1898-10-03          White
# 18              Sucha, Galicia, Austria    2006-06-22          White
#
#           religion sexual_orientation  year_of_award          award  \
# 10  Roman Catholic           Straight           1939  Best Director
# 12  Roman Catholic           Bisexual           1941  Best Director
# 14              Na           Straight           1943  Best Director
# 16              Na           Straight           1945  Best Director
# 18          Jewish           Straight           1946  Best Director
#
#                          movie         person
# 10  You Can't Take It with You    Frank Capra
# 12         The Grapes of Wrath      John Ford
# 14                Mrs. Miniver  William Wyler
# 16                Going My Way    Leo McCarey
# 18            The Lost Weekend   Billy Wilder

# %%
oscars_short.iloc[5]
# Out:
# birthplace              Glasgow, Scotland
# date_of_birth         1886-02-02 00:00:00
# race_ethnicity                      White
# religion                               Na
# sexual_orientation               Straight
# year_of_award                        1934
# award                       Best Director
# movie                           Cavalcade
# person                        Frank Lloyd
# Name: 5, dtype: object

# %%
oscars_short.loc[5]
# Out:
# birthplace              Glasgow, Scotland
# date_of_birth         1886-02-02 00:00:00
# race_ethnicity                      White
# religion                               Na
# sexual_orientation               Straight
# year_of_award                        1934
# award                       Best Director
# movie                           Cavalcade
# person                        Frank Lloyd
# Name: 5, dtype: object

# %%
oscars_short.loc[[5,10]]
# Out:
#                    birthplace date_of_birth race_ethnicity        religion  \
# 5           Glasgow, Scotland    1886-02-02          White              Na
# 10  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
#
#    sexual_orientation  year_of_award          award  \
# 5            Straight           1934  Best Director
# 10           Straight           1939  Best Director
#
#                          movie       person
# 5                    Cavalcade  Frank Lloyd
# 10  You Can't Take It with You  Frank Capra

# %% [markdown]
# ### Selecting Data Frame Columns and Rows simultaneously
#
# #### _loc_ and _iloc_ allows us to do it

# %%
oscars_short.head(10)
# Out:
#                   birthplace date_of_birth race_ethnicity        religion  \
# 0          Chisinau, Moldova    1895-09-30          White              Na
# 1          Glasgow, Scotland    1886-02-02          White              Na
# 2          Chisinau, Moldova    1895-09-30          White              Na
# 3                Chicago, Il    1899-02-23          White              Na
# 4         Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# 5          Glasgow, Scotland    1886-02-02          White              Na
# 6  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
# 7         Cape Elizabeth, Me    1894-02-01          White  Roman Catholic
# 8  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
# 9            Los Angeles, Ca    1898-10-03          White              Na
#
#   sexual_orientation  year_of_award          award  \
# 0           Straight           1927  Best Director
# 1           Straight           1930  Best Director
# 2           Straight           1931  Best Director
# 3           Straight           1932  Best Director
# 4           Straight           1933  Best Director
# 5           Straight           1934  Best Director
# 6           Straight           1935  Best Director
# 7           Bisexual           1936  Best Director
# 8           Straight           1937  Best Director
# 9           Straight           1938  Best Director
#
#                             movie           person
# 0             Two Arabian Knights  Lewis Milestone
# 1                 The Divine Lady      Frank Lloyd
# 2  All Quiet on the Western Front  Lewis Milestone
# 3                          Skippy    Norman Taurog
# 4                        Bad Girl    Frank Borzage
# 5                       Cavalcade      Frank Lloyd
# 6           It Happened One Night      Frank Capra
# 7                    The Informer        John Ford
# 8          Mr. Deeds Goes to Town      Frank Capra
# 9                 The Awful Truth      Leo McCarey

# %%
oscars_short.iloc[1,5]
# Out:
# 1930

# %%
oscars_short.iloc[:3,:5]
# Out:
#           birthplace date_of_birth race_ethnicity religion sexual_orientation
# 0  Chisinau, Moldova    1895-09-30          White       Na           Straight
# 1  Glasgow, Scotland    1886-02-02          White       Na           Straight
# 2  Chisinau, Moldova    1895-09-30          White       Na           Straight

# %%
oscars_short.iloc[:,[2,5]]
# Out:
#     race_ethnicity  year_of_award
# 0            White           1927
# 1            White           1930
# 2            White           1931
# 3            White           1932
# 4            White           1933
# ..             ...            ...
# 436          White           2006
# 437          White           2009
# 438          White           1977
# 439          White           1999
# 440          White           1949
#
# [441 rows x 2 columns]

# %%
oscars_short.loc[:,['birthplace','date_of_birth']]
# Out:
#               birthplace date_of_birth
# 0      Chisinau, Moldova    1895-09-30
# 1      Glasgow, Scotland    1886-02-02
# 2      Chisinau, Moldova    1895-09-30
# 3            Chicago, Il    1899-02-23
# 4     Salt Lake City, Ut    1894-04-23
# ..                   ...           ...
# 436      London, England    1971-03-07
# 437  Manchester, England    2056-10-20
# 438          Chicago, Il    2022-07-26
# 439           Laurel, Ne    2028-08-31
# 440           Nevada, Mo    2006-08-05
#
# [441 rows x 2 columns]

# %%
oscars_short.head(10)
# Out:
#                   birthplace date_of_birth race_ethnicity        religion  \
# 0          Chisinau, Moldova    1895-09-30          White              Na
# 1          Glasgow, Scotland    1886-02-02          White              Na
# 2          Chisinau, Moldova    1895-09-30          White              Na
# 3                Chicago, Il    1899-02-23          White              Na
# 4         Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# 5          Glasgow, Scotland    1886-02-02          White              Na
# 6  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
# 7         Cape Elizabeth, Me    1894-02-01          White  Roman Catholic
# 8  Bisacquino, Sicily, Italy    1897-05-18          White  Roman Catholic
# 9            Los Angeles, Ca    1898-10-03          White              Na
#
#   sexual_orientation  year_of_award          award  \
# 0           Straight           1927  Best Director
# 1           Straight           1930  Best Director
# 2           Straight           1931  Best Director
# 3           Straight           1932  Best Director
# 4           Straight           1933  Best Director
# 5           Straight           1934  Best Director
# 6           Straight           1935  Best Director
# 7           Bisexual           1936  Best Director
# 8           Straight           1937  Best Director
# 9           Straight           1938  Best Director
#
#                             movie           person
# 0             Two Arabian Knights  Lewis Milestone
# 1                 The Divine Lady      Frank Lloyd
# 2  All Quiet on the Western Front  Lewis Milestone
# 3                          Skippy    Norman Taurog
# 4                        Bad Girl    Frank Borzage
# 5                       Cavalcade      Frank Lloyd
# 6           It Happened One Night      Frank Capra
# 7                    The Informer        John Ford
# 8          Mr. Deeds Goes to Town      Frank Capra
# 9                 The Awful Truth      Leo McCarey

# %%
oscars_short.iloc[1:10:2,1]
# Out:
# 1   1886-02-02
# 3   1899-02-23
# 5   1886-02-02
# 7   1894-02-01
# 9   1898-10-03
# Name: date_of_birth, dtype: datetime64[ns]

# %%
oscars_short.loc[1:10:2,'date_of_birth']
# Out:
# 1   1886-02-02
# 3   1899-02-23
# 5   1886-02-02
# 7   1894-02-01
# 9   1898-10-03
# Name: date_of_birth, dtype: datetime64[ns]

# %% [markdown]
# ### Boolean indexing
# We will try to find out which of the business with more than 100 reviews. To do that, we will start by creating a serie with boolean elements for each of the business:

# %%
oscars_last_20_years=oscars_short['year_of_award']>1999

# %%
oscars_last_20_years
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 436     True
# 437     True
# 438    False
# 439    False
# 440    False
# Name: year_of_award, Length: 441, dtype: bool

# %% [markdown]
# As we saw, we can _sum_ boolean values, adding 1 if it is True and 0 if False. So if we want to know how many of them are dated in the last 20years, all we need to know is to sum up the values:

# %%
oscars_last_20_years.sum()
# Out:
# 82

# %% [markdown]
# If we want to know the % we can use _mean_ and multiply by 100:

# %%
oscars_last_20_years.mean() * 100
# Out:
# 18.594104308390023

# %%
oscars_last_20_years.describe()
# Out:
# count       441
# unique        2
# top       False
# freq        359
# Name: year_of_award, dtype: object

# %%
oscars_last_20_years.value_counts()
# Out:
# False    359
# True      82
# Name: year_of_award, dtype: int64

# %% [markdown]
# We just created a boolean series by comparing a column with a condition. We can also create a series based on two different columns.

# %%
oscars_best_director=oscars_short.award.str.contains('Best Director')

# %%
oscars_best_director.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: award, dtype: bool

# %%
oscars_best_director.value_counts()
# Out:
# False    350
# True      91
# Name: award, dtype: int64

# %% [markdown]
# we can combine both:

# %%
oscars_last_20_years & oscars_best_director
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 436    False
# 437     True
# 438    False
# 439    False
# 440    False
# Length: 441, dtype: bool

# %%
(oscars_last_20_years & oscars_best_director).value_counts()
# Out:
# False    425
# True      16
# dtype: int64

# %% [markdown]
# ### Filtering with boolean indexing
#
# We will use the boolean series created to filter the information of the records that match the conditions

# %%
oscars_short[oscars_last_20_years]
# Out:
#                       birthplace date_of_birth race_ethnicity        religion  \
# 41            St. Louis Park, Mn    2054-11-29          White          Jewish
# 73   Reading, Berkshire, England    2065-08-01          White              Na
# 74                   Atlanta, Ga    2063-01-14          White         Atheist
# 75                    Duncan, Ok    2054-03-01          White              Na
# 76                 Paris, France    2033-08-18          White        See Note
# ..                           ...           ...            ...             ...
# 430                  Lincoln, Ne    1974-07-30          White              Na
# 433                 Woodlawn, Md    2067-12-11          Black              Na
# 434                 La Jolla, Ca    2059-08-14          White              Na
# 436              London, England    1971-03-07          White          Jewish
# 437          Manchester, England    2056-10-20          White  Roman Catholic
#
#     sexual_orientation  year_of_award                    award  \
# 41            Straight           2008            Best Director
# 73            Straight           2000            Best Director
# 74            Straight           2001            Best Director
# 75            Straight           2002            Best Director
# 76            Straight           2003            Best Director
# ..                 ...            ...                      ...
# 430           Straight           2005             Best Actress
# 433           Straight           2010  Best Supporting Actress
# 434           Straight           2001  Best Supporting Actress
# 436           Straight           2006  Best Supporting Actress
# 437           Straight           2009            Best Director
#
#                       movie             person
# 41   No Country for Old Men          Joel Coen
# 73          American Beauty         Sam Mendes
# 74                  Traffic  Steven Soderbergh
# 75         A Beautiful Mind         Ron Howard
# 76              The Pianist     Roman Polanski
# ..                      ...                ...
# 430     Million Dollar Baby       Hilary Swank
# 433                Precious           Mo'Nique
# 434                 Pollock  Marcia Gay Harden
# 436   The Constant Gardener       Rachel Weisz
# 437     Slumdog Millionaire        Danny Boyle
#
# [82 rows x 9 columns]

# %%
oscars_short[oscars_best_director]
# Out:
#                   birthplace date_of_birth race_ethnicity        religion  \
# 0          Chisinau, Moldova    1895-09-30          White              Na
# 1          Glasgow, Scotland    1886-02-02          White              Na
# 2          Chisinau, Moldova    1895-09-30          White              Na
# 3                Chicago, Il    1899-02-23          White              Na
# 4         Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# ..                       ...           ...            ...             ...
# 86          Pingtung, Taiwan    2054-10-23          Asian              Na
# 416  Sucha, Galicia, Austria    2006-06-22          White          Jewish
# 419            New York City    2039-02-03          White              Na
# 437      Manchester, England    2056-10-20          White  Roman Catholic
# 440               Nevada, Mo    2006-08-05          White              Na
#
#     sexual_orientation  year_of_award          award  \
# 0             Straight           1927  Best Director
# 1             Straight           1930  Best Director
# 2             Straight           1931  Best Director
# 3             Straight           1932  Best Director
# 4             Straight           1933  Best Director
# ..                 ...            ...            ...
# 86            Straight           2013  Best Director
# 416           Straight           1961  Best Director
# 419           Straight           1979  Best Director
# 437           Straight           2009  Best Director
# 440           Straight           1949  Best Director
#
#                                 movie           person
# 0                 Two Arabian Knights  Lewis Milestone
# 1                     The Divine Lady      Frank Lloyd
# 2      All Quiet on the Western Front  Lewis Milestone
# 3                              Skippy    Norman Taurog
# 4                            Bad Girl    Frank Borzage
# ..                                ...              ...
# 86                         Life of Pi          Ang Lee
# 416                     The Apartment     Billy Wilder
# 419                   The Deer Hunter   Michael Cimino
# 437               Slumdog Millionaire      Danny Boyle
# 440  The Treasure of the Sierra Madre      John Huston
#
# [91 rows x 9 columns]

# %%
oscars_short[(oscars_last_20_years&oscars_best_director)]
# Out:
#                       birthplace date_of_birth race_ethnicity        religion  \
# 41            St. Louis Park, Mn    2054-11-29          White          Jewish
# 73   Reading, Berkshire, England    2065-08-01          White              Na
# 74                   Atlanta, Ga    2063-01-14          White         Atheist
# 75                    Duncan, Ok    2054-03-01          White              Na
# 76                 Paris, France    2033-08-18          White        See Note
# 77       Wellington, New Zealand    2061-10-31          White              Na
# 78             San Francisco, Ca    2030-05-31          White              Na
# 79              Pingtung, Taiwan    2054-10-23          Asian              Na
# 80                  Flushing, Ny    2042-11-17          White  Roman Catholic
# 81            St. Louis Park, Mn    2057-09-21          White          Jewish
# 82           Manchester, England    2056-10-20          White  Roman Catholic
# 83                San Carlos, Ca    2051-11-27          White              Na
# 84               London, England    1972-01-01          White              Na
# 85                 Paris, France    2067-03-29          White          Jewish
# 86              Pingtung, Taiwan    2054-10-23          Asian              Na
# 437          Manchester, England    2056-10-20          White  Roman Catholic
#
#     sexual_orientation  year_of_award          award  \
# 41            Straight           2008  Best Director
# 73            Straight           2000  Best Director
# 74            Straight           2001  Best Director
# 75            Straight           2002  Best Director
# 76            Straight           2003  Best Director
# 77            Straight           2004  Best Director
# 78            Straight           2005  Best Director
# 79            Straight           2006  Best Director
# 80            Straight           2007  Best Director
# 81            Straight           2008  Best Director
# 82            Straight           2009  Best Director
# 83            Straight           2009  Best Director
# 84                  Na           2011  Best Director
# 85            Straight           2012  Best Director
# 86            Straight           2013  Best Director
# 437           Straight           2009  Best Director
#
#                                          movie               person
# 41                      No Country for Old Men            Joel Coen
# 73                             American Beauty           Sam Mendes
# 74                                     Traffic    Steven Soderbergh
# 75                            A Beautiful Mind           Ron Howard
# 76                                 The Pianist       Roman Polanski
# 77   The Lord of the Rings: Return of the King        Peter Jackson
# 78                         Million Dollar Baby       Clint Eastwood
# 79                          Brokeback Mountain              Ang Lee
# 80                                The Departed      Martin Scorsese
# 81                      No Country for Old Men           Ethan Coen
# 82                         Slumdog Millionaire          Danny Boyle
# 83                             The Hurt Locker      Kathryn Bigelow
# 84                           The King's Speech           Tom Hooper
# 85                                  The Artist  Michel Hazanavicius
# 86                                  Life of Pi              Ang Lee
# 437                        Slumdog Millionaire          Danny Boyle

# %%
oscars_short.count()
# Out:
# birthplace            441
# date_of_birth         440
# race_ethnicity        441
# religion              441
# sexual_orientation    441
# year_of_award         441
# award                 441
# movie                 441
# person                441
# dtype: int64

# %%
oscars_short.drop_duplicates(inplace=True)

# %% [markdown]
# #
# #
# #
# #  Data Visualization
#
# * Analizing viariables

# %% [markdown]
# ### Histograms

# %%
fig=plt.figure()
ax = fig.add_subplot(111)

plt.title('Year of Award variable: Histogram',fontsize=16,fontweight='bold')
ax.set_xlabel('year of award')
oscars_short['year_of_award'].plot.hist(color='darksalmon', figsize=(8, 4))

plt.show()

# %%
# the same, but horizontal
fig=plt.figure()
ax = fig.add_subplot(111)

plt.title('Year of Award variable: Histogram',fontsize=16,fontweight='bold')
ax.set_xlabel('year of award')
oscars_short['year_of_award'].plot.hist(orientation='horizontal',color='lightblue', figsize=(8, 4))

plt.show()

# %% [markdown]
# ### Density Plots

# %%
fig=plt.figure()
ax = fig.add_subplot(111)

plt.title('Year of Award variable: Histogram',fontsize=16,fontweight='bold')
ax.set_xlabel('year of award')
oscars_short['year_of_award'].plot.kde(color='lightgreen', figsize=(8, 4))

plt.show()

# %%
fig=plt.figure()
ax = fig.add_subplot(111)

plt.title('Year of Award variable: Histogram & KDE',fontsize=16,fontweight='bold')
ax.set_xlabel('year of award')
oscars_short['year_of_award'].plot.hist(color='lightsteelblue', figsize=(8, 4), density=True)
oscars_short['year_of_award'].plot.kde(color='darkblue', ax=ax, secondary_y=True)

ax.set_ylabel('Density')
plt.show()

# %%
# Density Plot and Histogram using sns
sns.distplot(oscars_short['year_of_award'], hist=True, kde=True, 
             bins=int(180/5), color = 'lightblue', 
             hist_kws={'edgecolor':'grey'},
             kde_kws={'linewidth': 4})

plt.xlabel('Year of Award')
plt.ylabel('Density')
plt.title('Other histogram & dencity plot')
# Out:
# Text(0.5, 1.0, 'Other histogram & dencity plot')

# %% [markdown]
# ### Bar Plot

# %%
oscars_per_person=oscars_short['person'].value_counts()
oscars_per_person
# Out:
# Katharine Hepburn      4
# John Ford              4
# Walter Brennan         3
# William Wyler          3
# Frank Capra            3
#                       ..
# Bob Fosse              1
# Paul Newman            1
# Margaret Rutherford    1
# Judi Dench             1
# Frank Sinatra          1
# Name: person, Length: 348, dtype: int64

# %%
type(oscars_per_person)
# Out:
# pandas.core.series.Series

# %%
oscars_per_person_df=oscars_per_person.to_frame()
oscars_per_person_df
# Out:
#                      person
# Katharine Hepburn         4
# John Ford                 4
# Walter Brennan            3
# William Wyler             3
# Frank Capra               3
# ...                     ...
# Bob Fosse                 1
# Paul Newman               1
# Margaret Rutherford       1
# Judi Dench                1
# Frank Sinatra             1
#
# [348 rows x 1 columns]

# %%
oscars_per_person_df.head(20).plot(kind='bar',figsize=(16,8),rot=85,title='Top Award Winners',color=(0.7, 0.2, 0.4, 0.6));
ax=plt.gca()
ax.set_ylabel('Oscars');
ax.set_xlabel('Name')
# Out:
# Text(0.5, 0, 'Name')

# %% [markdown]
# ### Scatter Plot

# %%
oscars_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 416 entries, 0 to 415
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   birthplace          416 non-null    object
#  1   date_of_birth       415 non-null    datetime64[ns]
#  2   race_ethnicity      416 non-null    object
#  3   religion            416 non-null    object
#  4   sexual_orientation  416 non-null    object
#  5   year_of_award       416 non-null    int64
#  6   award               416 non-null    object
#  7   movie               416 non-null    object
#  8   person              416 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 32.5+ KB

# %%
oscars_short['age_at_award']=oscars_short['year_of_award']-(oscars_short['date_of_birth'].dt.year)

# %%
oscars_short
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova    1895-09-30          White              Na
# 1      Glasgow, Scotland    1886-02-02          White              Na
# 2      Chisinau, Moldova    1895-09-30          White              Na
# 3            Chicago, Il    1899-02-23          White              Na
# 4     Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 411         Woodlawn, Md    2067-12-11          Black              Na
# 412        New York City    2060-09-14          White              Na
# 413       Montgomery, Al    1972-05-25          Black              Na
# 414         Brooklyn, Ny    1982-11-12          White       Christian
# 415  Mexico City, Mexico    1983-03-01          Black              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 411           Straight           2010  Best Supporting Actress
# 412           Straight           2011  Best Supporting Actress
# 413                 Na           2012  Best Supporting Actress
# 414           Straight           2013  Best Supporting Actress
# 415                 Na           2014  Best Supporting Actress
#
#                               movie           person  age_at_award
# 0               Two Arabian Knights  Lewis Milestone          32.0
# 1                   The Divine Lady      Frank Lloyd          44.0
# 2    All Quiet on the Western Front  Lewis Milestone          36.0
# 3                            Skippy    Norman Taurog          33.0
# 4                          Bad Girl    Frank Borzage          39.0
# ..                              ...              ...           ...
# 411                        Precious         Mo'Nique         -57.0
# 412                     The Fighter      Melissa Leo         -49.0
# 413                        The Help  Octavia Spencer          40.0
# 414                 Les MisÌ©rables    Anne Hathaway          31.0
# 415                12 Years a Slave   Lupita Nyong'o          31.0
#
# [416 rows x 10 columns]

# %%
(oscars_short['age_at_award']>0).value_counts()
# Out:
# False    316
# True     100
# Name: age_at_award, dtype: int64

# %%
from datetime import datetime
hundred_years=datetime.strptime('0100-01-01','%Y-%m-%d')
print(hundred_years)
# Out:
# 0100-01-01 00:00:00

# %%
oscars_short['year_of_birth']=oscars_short.loc[:,'date_of_birth'].dt.year
oscars_short['age_at_award']=oscars_short['year_of_award']-(oscars_short['date_of_birth'].dt.year)
oscars_short.loc[oscars_short['age_at_award']<1,'year_of_birth'] = oscars_short.loc[oscars_short['age_at_award']<1,'year_of_birth'] - 100

# %%
oscars_short['age_at_award']=oscars_short['year_of_award']-(oscars_short['year_of_birth'])

# %%
oscars_short.loc[(oscars_short['age_at_award']<1),:]
# Out:
# Empty DataFrame
# Columns: [birthplace, date_of_birth, race_ethnicity, religion, sexual_orientation, year_of_award, award, movie, person, age_at_award, year_of_birth]
# Index: []

# %%
oscars_short
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova    1895-09-30          White              Na
# 1      Glasgow, Scotland    1886-02-02          White              Na
# 2      Chisinau, Moldova    1895-09-30          White              Na
# 3            Chicago, Il    1899-02-23          White              Na
# 4     Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 411         Woodlawn, Md    2067-12-11          Black              Na
# 412        New York City    2060-09-14          White              Na
# 413       Montgomery, Al    1972-05-25          Black              Na
# 414         Brooklyn, Ny    1982-11-12          White       Christian
# 415  Mexico City, Mexico    1983-03-01          Black              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 411           Straight           2010  Best Supporting Actress
# 412           Straight           2011  Best Supporting Actress
# 413                 Na           2012  Best Supporting Actress
# 414           Straight           2013  Best Supporting Actress
# 415                 Na           2014  Best Supporting Actress
#
#                               movie           person  age_at_award  \
# 0               Two Arabian Knights  Lewis Milestone          32.0
# 1                   The Divine Lady      Frank Lloyd          44.0
# 2    All Quiet on the Western Front  Lewis Milestone          36.0
# 3                            Skippy    Norman Taurog          33.0
# 4                          Bad Girl    Frank Borzage          39.0
# ..                              ...              ...           ...
# 411                        Precious         Mo'Nique          43.0
# 412                     The Fighter      Melissa Leo          51.0
# 413                        The Help  Octavia Spencer          40.0
# 414                 Les MisÌ©rables    Anne Hathaway          31.0
# 415                12 Years a Slave   Lupita Nyong'o          31.0
#
#      year_of_birth
# 0           1895.0
# 1           1886.0
# 2           1895.0
# 3           1899.0
# 4           1894.0
# ..             ...
# 411         1967.0
# 412         1960.0
# 413         1972.0
# 414         1982.0
# 415         1983.0
#
# [416 rows x 11 columns]

# %%
oscars_short.plot.scatter('year_of_award','age_at_award', title='Relationship between Year of Award and Age',alpha=0.25,figsize=(12,8));
ax=plt.gca()
ax.set_ylabel('Age')
ax.set_xlabel('Year');

# %%
oscars_short.corr()
# Out:
#                year_of_award  age_at_award  year_of_birth
# year_of_award       1.000000      0.123459       0.875404
# age_at_award        0.123459      1.000000      -0.371617
# year_of_birth       0.875404     -0.371617       1.000000

# %%
cor = oscars_short.corr().abs()

import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl



fig = plt.figure()
fig, ax = plt.subplots(1,1, figsize=(8,8))
heatplot = ax.imshow(cor, cmap='BuPu')
ax.set_xticklabels(cor.columns)
ax.set_yticklabels(cor.index)

tick_spacing = 1
ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax.set_title("Relationship between numeric columns")
ax.set_xlabel('Columns')
ax.set_ylabel('Columns')
# Out:
# Text(0, 0.5, 'Columns')

# %% [markdown]
# #
# #
# #
# #
# ##  Grouping for Aggregation, filtration and transformation

# %% [markdown]
# The most common use of a _groupby_ is performing an aggregation (which takes several values and converts them in one single value).
#
# In order to do this, we will define an __aggregating column__ (from where we take the value to aggregate) and an __aggregating function__ (how do we aggregate).
#
# Some common aggregating functions are _mean, sum, max, min, count_, etc...

# %% [markdown]
# The easiest way to do it, groupby + apply:

# %%
oscars_short
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova    1895-09-30          White              Na
# 1      Glasgow, Scotland    1886-02-02          White              Na
# 2      Chisinau, Moldova    1895-09-30          White              Na
# 3            Chicago, Il    1899-02-23          White              Na
# 4     Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 411         Woodlawn, Md    2067-12-11          Black              Na
# 412        New York City    2060-09-14          White              Na
# 413       Montgomery, Al    1972-05-25          Black              Na
# 414         Brooklyn, Ny    1982-11-12          White       Christian
# 415  Mexico City, Mexico    1983-03-01          Black              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 411           Straight           2010  Best Supporting Actress
# 412           Straight           2011  Best Supporting Actress
# 413                 Na           2012  Best Supporting Actress
# 414           Straight           2013  Best Supporting Actress
# 415                 Na           2014  Best Supporting Actress
#
#                               movie           person  age_at_award  \
# 0               Two Arabian Knights  Lewis Milestone          32.0
# 1                   The Divine Lady      Frank Lloyd          44.0
# 2    All Quiet on the Western Front  Lewis Milestone          36.0
# 3                            Skippy    Norman Taurog          33.0
# 4                          Bad Girl    Frank Borzage          39.0
# ..                              ...              ...           ...
# 411                        Precious         Mo'Nique          43.0
# 412                     The Fighter      Melissa Leo          51.0
# 413                        The Help  Octavia Spencer          40.0
# 414                 Les MisÌ©rables    Anne Hathaway          31.0
# 415                12 Years a Slave   Lupita Nyong'o          31.0
#
#      year_of_birth
# 0           1895.0
# 1           1886.0
# 2           1895.0
# 3           1899.0
# 4           1894.0
# ..             ...
# 411         1967.0
# 412         1960.0
# 413         1972.0
# 414         1982.0
# 415         1983.0
#
# [416 rows x 11 columns]

# %%
grouped=oscars_short.groupby(['award']).agg({'age_at_award':['mean','count']}) 
grouped
# Out:
#                         age_at_award
#                                 mean count
# award
# Best Actor                 45.046512    86
# Best Actress               36.850575    87
# Best Director              47.279070    86
# Best Supporting Actor      50.666667    78
# Best Supporting Actress    40.641026    78

# %%
grouped=oscars_short.groupby(['year_of_award']).agg({'age_at_award':['mean','count']}) 
grouped
# Out:
#               age_at_award
#                       mean count
# year_of_award
# 1927             32.000000     1
# 1929             34.000000     2
# 1930             42.600000     5
# 1931             50.666667     3
# 1932             37.333333     3
# ...                    ...   ...
# 2010             51.000000     4
# 2011             41.600000     5
# 2012             54.200000     5
# 2013             45.200000     5
# 2014             41.000000     4
#
# [87 rows x 2 columns]

# %%
grouped.loc[grouped[('age_at_award','count')]>5,:].sort_values(('age_at_award','mean'),ascending=False).head(10)
# Out:
#               age_at_award
#                       mean count
# year_of_award
# 1969             53.714286     7
# 2007             53.166667     6
# 1976             49.166667     6
# 1990             47.166667     6
# 1973             44.833333     6
# 2003             44.166667     6
# 2009             43.166667     6
# 1997             41.833333     6
# 1961             41.000000     6
# 1938             39.666667     6

# %%
oscars_short.groupby('award').mean().loc[:,'age_at_award'].plot(kind='bar',title='Average age by Award category',linewidth=2,figsize=(10,6), color='lightpink');
ax=plt.gca()
ax.set_ylabel('Average Age');
ax.set_xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')

# %%
grouped=oscars_short.groupby(['movie'])
grouped.head()
# Out:
#               birthplace date_of_birth race_ethnicity        religion  \
# 0      Chisinau, Moldova    1895-09-30          White              Na
# 1      Glasgow, Scotland    1886-02-02          White              Na
# 2      Chisinau, Moldova    1895-09-30          White              Na
# 3            Chicago, Il    1899-02-23          White              Na
# 4     Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# ..                   ...           ...            ...             ...
# 411         Woodlawn, Md    2067-12-11          Black              Na
# 412        New York City    2060-09-14          White              Na
# 413       Montgomery, Al    1972-05-25          Black              Na
# 414         Brooklyn, Ny    1982-11-12          White       Christian
# 415  Mexico City, Mexico    1983-03-01          Black              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1930            Best Director
# 2             Straight           1931            Best Director
# 3             Straight           1932            Best Director
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 411           Straight           2010  Best Supporting Actress
# 412           Straight           2011  Best Supporting Actress
# 413                 Na           2012  Best Supporting Actress
# 414           Straight           2013  Best Supporting Actress
# 415                 Na           2014  Best Supporting Actress
#
#                               movie           person  age_at_award  \
# 0               Two Arabian Knights  Lewis Milestone          32.0
# 1                   The Divine Lady      Frank Lloyd          44.0
# 2    All Quiet on the Western Front  Lewis Milestone          36.0
# 3                            Skippy    Norman Taurog          33.0
# 4                          Bad Girl    Frank Borzage          39.0
# ..                              ...              ...           ...
# 411                        Precious         Mo'Nique          43.0
# 412                     The Fighter      Melissa Leo          51.0
# 413                        The Help  Octavia Spencer          40.0
# 414                 Les MisÌ©rables    Anne Hathaway          31.0
# 415                12 Years a Slave   Lupita Nyong'o          31.0
#
#      year_of_birth
# 0           1895.0
# 1           1886.0
# 2           1895.0
# 3           1899.0
# 4           1894.0
# ..             ...
# 411         1967.0
# 412         1960.0
# 413         1972.0
# 414         1982.0
# 415         1983.0
#
# [416 rows x 11 columns]

# %%
grouped.get_group('Cabaret')
# Out:
#           birthplace date_of_birth race_ethnicity religion sexual_orientation  \
# 46       Chicago, Il    2027-06-23          White       Na           Straight
# 209    Cleveland, Oh    2032-04-11          White   Jewish                Gay
# 296  Los Angeles, Ca    2046-03-12          White       Na                 Na
#
#      year_of_award                  award    movie         person  \
# 46            1973          Best Director  Cabaret      Bob Fosse
# 209           1973  Best Supporting Actor  Cabaret      Joel Grey
# 296           1973           Best Actress  Cabaret  Liza Minnelli
#
#      age_at_award  year_of_birth
# 46           46.0         1927.0
# 209          41.0         1932.0
# 296          27.0         1946.0

# %% [markdown]
# #
# ###  Grouping by multiple columns

# %%
grouped=oscars_short.groupby(['person','award']).size()
grouped
# Out:
# person          award
# Adrien Brody    Best Actor                 1
# Al Pacino       Best Actor                 1
# Alan Arkin      Best Supporting Actor      1
# Alec Guinness   Best Actor                 1
# Alice Brady     Best Supporting Actress    1
#                                           ..
# William Holden  Best Actor                 1
# William Hurt    Best Actor                 1
# William Wyler   Best Director              3
# Woody Allen     Best Director              1
# Yul Brynner     Best Actor                 1
# Length: 360, dtype: int64

# %%
grouped=oscars_short.groupby(['person','award']).size().sort_values(ascending=False)
grouped
# Out:
# person               award
# Katharine Hepburn    Best Actress               4
# John Ford            Best Director              4
# William Wyler        Best Director              3
# Frank Capra          Best Director              3
# Daniel Day-Lewis     Best Actor                 3
#                                                ..
# Margaret Rutherford  Best Supporting Actress    1
# Marie Dressler       Best Actress               1
# Marion Cotillard     Best Actress               1
# Marisa Tomei         Best Supporting Actress    1
# Adrien Brody         Best Actor                 1
# Length: 360, dtype: int64

# %%
grouped=oscars_short.groupby(['person','award']).size().nlargest(20)
grouped
# Out:
# person             award
# John Ford          Best Director              4
# Katharine Hepburn  Best Actress               4
# Daniel Day-Lewis   Best Actor                 3
# Frank Capra        Best Director              3
# Walter Brennan     Best Supporting Actor      3
# William Wyler      Best Director              3
# Ang Lee            Best Director              2
# Anthony Quinn      Best Supporting Actor      2
# Bette Davis        Best Actress               2
# Billy Wilder       Best Director              2
# Christoph Waltz    Best Supporting Actor      2
# Clint Eastwood     Best Director              2
# David Lean         Best Director              2
# Dianne Wiest       Best Supporting Actress    2
# Dustin Hoffman     Best Actor                 2
# Elia Kazan         Best Director              2
# Elizabeth Taylor   Best Actress               2
# Frank Lloyd        Best Director              2
# Fred Zinnemann     Best Director              2
# Gary Cooper        Best Actor                 2
# dtype: int64

# %%
#other alternative, without group by
oscars_short['person'].value_counts().nlargest(10)
# Out:
# Katharine Hepburn    4
# John Ford            4
# Walter Brennan       3
# William Wyler        3
# Frank Capra          3
# Ingrid Bergman       3
# Jack Nicholson       3
# Meryl Streep         3
# Daniel Day-Lewis     3
# Frank Lloyd          2
# Name: person, dtype: int64

# %%
#other alternative, without group by
oscars_short['person'].value_counts().nsmallest(5)
# Out:
# Burl Ives       1
# John Mills      1
# Sissy Spacek    1
# Van Heflin      1
# Alice Brady     1
# Name: person, dtype: int64

# %% [markdown]
# If we want to create a dataframe, with the total number of elements per group (size), we can reset the index like following...

# %%
oscars_short_by_religion=oscars_short.groupby(['award','religion']).size()
oscars_short_by_religion=oscars_short_by_religion.reset_index()
oscars_short_by_religion
col_rename={0:'count_religion'}
oscars_short_by_religion=oscars_short_by_religion.rename(columns=col_rename)
oscars_short_by_religion
# Out:
#                       award               religion  count_religion
# 0                Best Actor  Anglican/episcopalian               1
# 1                Best Actor                Atheist               2
# 2                Best Actor                Baptist               1
# 3                Best Actor   Born-Again Christian               2
# 4                Best Actor                  Deist               3
# 5                Best Actor                 Jewish               7
# 6                Best Actor               Lutheran               3
# 7                Best Actor                     Na              44
# 8                Best Actor           Presbyterian               1
# 9                Best Actor             Protestant               3
# 10               Best Actor                 Quaker               1
# 11               Best Actor         Roman Catholic              18
# 12             Best Actress                Atheist               7
# 13             Best Actress                Baptist               1
# 14             Best Actress   Born-Again Christian               2
# 15             Best Actress      Christian Science               3
# 16             Best Actress    Disciples of Christ               1
# 17             Best Actress                  Hindu               1
# 18             Best Actress                 Jewish               8
# 19             Best Actress                     Na              50
# 20             Best Actress         Roman Catholic              13
# 21             Best Actress                 Sufism               1
# 22            Best Director                Atheist               4
# 23            Best Director                Baptist               2
# 24            Best Director                 Jewish              17
# 25            Best Director                     Na              50
# 26            Best Director           Presbyterian               1
# 27            Best Director         Roman Catholic              12
# 28            Best Director               See Note               1
# 29    Best Supporting Actor  Anglican/episcopalian               1
# 30    Best Supporting Actor                Atheist               1
# 31    Best Supporting Actor               Buddhist               1
# 32    Best Supporting Actor                 Jewish               8
# 33    Best Supporting Actor                     Na              58
# 34    Best Supporting Actor             Protestant               2
# 35    Best Supporting Actor         Roman Catholic               7
# 36  Best Supporting Actress               Agnostic               1
# 37  Best Supporting Actress                Atheist               2
# 38  Best Supporting Actress                Baptist               1
# 39  Best Supporting Actress               Buddhist               3
# 40  Best Supporting Actress              Christian               2
# 41  Best Supporting Actress      Congregationalist               1
# 42  Best Supporting Actress                 Jewish               5
# 43  Best Supporting Actress              Methodist               1
# 44  Best Supporting Actress                     Na              54
# 45  Best Supporting Actress                 Quaker               1
# 46  Best Supporting Actress         Roman Catholic               7

# %% [markdown]
# #### As we saw before, we can apply more than one operation at the same time

# %%
grouped=oscars_short.groupby(['year_of_award']).agg({'age_at_award':['mean','count']}) 
grouped.head(5)
# Out:
#               age_at_award
#                       mean count
# year_of_award
# 1927             32.000000     1
# 1929             34.000000     2
# 1930             42.600000     5
# 1931             50.666667     3
# 1932             37.333333     3

# %% [markdown]
# ####  We can even apply different operations to different columns

# %%
grouped=oscars_short.groupby(['year_of_award']).agg({'age_at_award':['mean','count'],'year_of_birth':'min','religion':['max','min']}) 
grouped.head(20)
# Out:
#               age_at_award       year_of_birth        religion  \
#                       mean count           min             max
# year_of_award
# 1927             32.000000     1        1895.0              Na
# 1929             34.000000     2        1884.0              Na
# 1930             42.600000     5        1868.0              Na
# 1931             50.666667     3        1868.0  Roman Catholic
# 1932             37.333333     3        1885.0              Na
# 1933             39.000000     1        1894.0  Roman Catholic
# 1934             36.666667     3        1886.0  Roman Catholic
# 1935             34.666667     3        1897.0  Roman Catholic
# 1936             41.000000     3        1883.0  Roman Catholic
# 1937             36.750000     4        1895.0  Roman Catholic
# 1938             39.666667     6        1892.0  Roman Catholic
# 1939             41.000000     5        1891.0  Roman Catholic
# 1940             39.500000     6        1883.0  Roman Catholic
# 1941             43.800000     5        1879.0  Roman Catholic
# 1942             45.000000     5        1880.0  Roman Catholic
# 1943             35.750000     4        1899.0  Roman Catholic
# 1944             50.200000     5        1877.0  Roman Catholic
# 1945             48.400000     5        1879.0  Roman Catholic
# 1946             41.600000     5        1901.0              Na
# 1947             36.600000     5        1897.0              Na
#
#
#                                  min
# year_of_award
# 1927                              Na
# 1929                              Na
# 1930                              Na
# 1931                              Na
# 1932                              Na
# 1933                  Roman Catholic
# 1934                         Atheist
# 1935                              Na
# 1936           Anglican/episcopalian
# 1937                          Jewish
# 1938                          Jewish
# 1939                              Na
# 1940                       Christian
# 1941               Christian Science
# 1942                              Na
# 1943                              Na
# 1944                              Na
# 1945                              Na
# 1946               Christian Science
# 1947                              Na

# %% [markdown]
# Inevitably, when using groupby, you will likely create a __MultiIndex__ in the columns or rows or both. DataFrames with MultiIndexes are more difficult to navigate and occasionally have confusing column names as well.

# %% [markdown]
# Doing this, we obtain a structure with two level of indexes. This difficults the access to the data.
#
# Because of that we will try to simplify the structure.
#
# Let's start by understanding how the index is presented at each level:

# %%
level0=grouped.columns.get_level_values(0)

# %%
level0
# Out:
# Index(['age_at_award', 'age_at_award', 'year_of_birth', 'religion',
#        'religion'],
#       dtype='object')

# %%
level1=grouped.columns.get_level_values(1)

# %%
level1
# Out:
# Index(['mean', 'count', 'min', 'max', 'min'], dtype='object')

# %% [markdown]
# We can see that we have two columns called min. We can only differenciate them by using both index levels (the sum of stars or the sum of reviews)
#
# We will try to reduce this structure, by concatenating both levels in the same column name.

# %%
grouped.columns = level0 + '_' + level1

# %% [markdown]
# Doing this, we now have 5 different columns with one index level:

# %%
grouped
# Out:
#                age_at_award_mean  age_at_award_count  year_of_birth_min  \
# year_of_award
# 1927                   32.000000                   1             1895.0
# 1929                   34.000000                   2             1884.0
# 1930                   42.600000                   5             1868.0
# 1931                   50.666667                   3             1868.0
# 1932                   37.333333                   3             1885.0
# ...                          ...                 ...                ...
# 2010                   51.000000                   4             1949.0
# 2011                   41.600000                   5             1960.0
# 2012                   54.200000                   5             1929.0
# 2013                   45.200000                   5             1954.0
# 2014                   41.000000                   4             1969.0
#
#                  religion_max religion_min
# year_of_award
# 1927                       Na           Na
# 1929                       Na           Na
# 1930                       Na           Na
# 1931           Roman Catholic           Na
# 1932                       Na           Na
# ...                       ...          ...
# 2010                       Na     Lutheran
# 2011                       Na       Jewish
# 2012                       Na       Jewish
# 2013                       Na    Christian
# 2014                       Na           Na
#
# [87 rows x 5 columns]

# %% [markdown]
# We can see that we still have 2 levels in the row index. We can reduce this using _reset_index()_

# %%
grouped.reset_index(inplace=True)

# %%
grouped
# Out:
#     year_of_award  age_at_award_mean  age_at_award_count  year_of_birth_min  \
# 0            1927          32.000000                   1             1895.0
# 1            1929          34.000000                   2             1884.0
# 2            1930          42.600000                   5             1868.0
# 3            1931          50.666667                   3             1868.0
# 4            1932          37.333333                   3             1885.0
# ..            ...                ...                 ...                ...
# 82           2010          51.000000                   4             1949.0
# 83           2011          41.600000                   5             1960.0
# 84           2012          54.200000                   5             1929.0
# 85           2013          45.200000                   5             1954.0
# 86           2014          41.000000                   4             1969.0
#
#       religion_max religion_min
# 0               Na           Na
# 1               Na           Na
# 2               Na           Na
# 3   Roman Catholic           Na
# 4               Na           Na
# ..             ...          ...
# 82              Na     Lutheran
# 83              Na       Jewish
# 84              Na       Jewish
# 85              Na    Christian
# 86              Na           Na
#
# [87 rows x 6 columns]

# %% [markdown]
# Pandas also allows us to define our own aggregate functions:

# %%
def add_one(x):
    return x.mean()+1 
     
oscars_short.groupby('award').agg({'age_at_award': ['mean', add_one]})
# Out:
#                         age_at_award
#                                 mean    add_one
# award
# Best Actor                 45.046512  46.046512
# Best Actress               36.850575  37.850575
# Best Director              47.279070  48.279070
# Best Supporting Actor      50.666667  51.666667
# Best Supporting Actress    40.641026  41.641026

# %%
add_one.__name__='PlusOne'
grouped=oscars_short.groupby('award').agg({'age_at_award': ['mean', add_one]})
grouped
# Out:
#                         age_at_award
#                                 mean    PlusOne
# award
# Best Actor                 45.046512  46.046512
# Best Actress               36.850575  37.850575
# Best Director              47.279070  48.279070
# Best Supporting Actor      50.666667  51.666667
# Best Supporting Actress    40.641026  41.641026

# %%
grouped=oscars_short.groupby('award')
print(type(grouped))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
grouped.ngroups
# Out:
# 5

# %%
grouped.get_group('Best Actor')
# Out:
#                                   birthplace date_of_birth race_ethnicity  \
# 87                    Rorschach, Switzerland    1884-07-23          White
# 88                              Columbus, Oh    1889-03-29          White
# 89                           London, England    1868-04-10          White
# 90                          Philadelphia, Pa    1878-04-28          White
# 91                           Kansas City, Mo    1885-04-01          White
# ..                                       ...           ...            ...
# 168                          Los Angeles, Ca    2049-12-04          White
# 169            Grayshott, Hampshire, England    2060-09-10          White
# 170  Rueil-Malmaison, Hauts-De-Seine, France    1972-06-19          White
# 171                          London, England    2057-04-29          White
# 172                               Uvalde, Tx    2069-11-04          White
#
#            religion sexual_orientation  year_of_award       award  \
# 87               Na           Bisexual           1929  Best Actor
# 88               Na           Straight           1930  Best Actor
# 89               Na           Straight           1930  Best Actor
# 90   Roman Catholic           Straight           1931  Best Actor
# 91               Na           Straight           1932  Best Actor
# ..              ...                ...            ...         ...
# 168        Lutheran           Straight           2010  Best Actor
# 169              Na           Straight           2011  Best Actor
# 170              Na           Straight           2012  Best Actor
# 171              Na           Straight           2013  Best Actor
# 172              Na           Straight           2014  Best Actor
#
#                   movie               person  age_at_award  year_of_birth
# 87     The Last Command        Emil Jannings          45.0         1884.0
# 88       In Old Arizona        Warner Baxter          41.0         1889.0
# 89             Desraeli        George Arliss          62.0         1868.0
# 90          A Free Soul     Lionel Barrymore          53.0         1878.0
# 91            The Champ        Wallace Beery          47.0         1885.0
# ..                  ...                  ...           ...            ...
# 168         Crazy Heart         Jeff Bridges          61.0         1949.0
# 169   The King's Speech          Colin Firth          51.0         1960.0
# 170          The Artist        Jean Dujardin          40.0         1972.0
# 171             Lincoln     Daniel Day-Lewis          56.0         1957.0
# 172  Dallas Buyers Club  Matthew McConaughey          45.0         1969.0
#
# [86 rows x 11 columns]

# %%
from IPython.display import display

for name, group in grouped:
        print(name)
        display(group.head(3))
# Out:
# Best Actor
#                 birthplace date_of_birth race_ethnicity religion  \
# 87  Rorschach, Switzerland    1884-07-23          White       Na
# 88            Columbus, Oh    1889-03-29          White       Na
# 89         London, England    1868-04-10          White       Na
#
#    sexual_orientation  year_of_award       award             movie  \
# 87           Bisexual           1929  Best Actor  The Last Command
# 88           Straight           1930  Best Actor    In Old Arizona
# 89           Straight           1930  Best Actor          Desraeli
#
#            person  age_at_award  year_of_birth
# 87  Emil Jannings          45.0         1884.0
# 88  Warner Baxter          41.0         1889.0
# 89  George Arliss          62.0         1868.0
# Best Actress
#                    birthplace date_of_birth race_ethnicity religion  \
# 251          Philadelphia, Pa    2006-10-06          White       Na
# 252  Toronto, Ontario, Canada    1892-04-08          White       Na
# 253  Montreal, Quebec, Canada    1902-08-10          White       Na
#
#     sexual_orientation  year_of_award         award         movie  \
# 251           Straight           1929  Best Actress    7th Heaven
# 252           Straight           1930  Best Actress      Coquette
# 253           Straight           1930  Best Actress  The Divorcee
#
#             person  age_at_award  year_of_birth
# 251   Janet Gaynor          23.0         1906.0
# 252  Mary Pickford          38.0         1892.0
# 253  Norma Shearer          28.0         1902.0
# Best Director
#           birthplace date_of_birth race_ethnicity religion sexual_orientation  \
# 0  Chisinau, Moldova    1895-09-30          White       Na           Straight
# 1  Glasgow, Scotland    1886-02-02          White       Na           Straight
# 2  Chisinau, Moldova    1895-09-30          White       Na           Straight
#
#    year_of_award          award                           movie  \
# 0           1927  Best Director             Two Arabian Knights
# 1           1930  Best Director                 The Divine Lady
# 2           1931  Best Director  All Quiet on the Western Front
#
#             person  age_at_award  year_of_birth
# 0  Lewis Milestone          32.0         1895.0
# 1      Frank Lloyd          44.0         1886.0
# 2  Lewis Milestone          36.0         1895.0
# Best Supporting Actor
#           birthplace date_of_birth race_ethnicity religion sexual_orientation  \
# 173   Swampscott, Ma    1894-07-25          White       Na           Straight
# 174  Vienna, Austria    1896-03-22          White       Na           Straight
# 175   Swampscott, Ma    1894-07-25          White       Na           Straight
#
#      year_of_award                  award                   movie  \
# 173           1938  Best Supporting Actor         Come and Get It
# 174           1938  Best Supporting Actor  The Life of Emile Zola
# 175           1939  Best Supporting Actor                Kentucky
#
#                  person  age_at_award  year_of_birth
# 173      Walter Brennan          44.0         1894.0
# 174  Joseph Schildkraut          42.0         1896.0
# 175      Walter Brennan          45.0         1894.0
# Best Supporting Actress
#           birthplace date_of_birth race_ethnicity religion sexual_orientation  \
# 338   Litchfield, Mn    1899-02-15          White       Na           Straight
# 339    New York City    1892-11-02          White       Na           Straight
# 340  Los Angeles, Ca    1891-12-07          White       Na           Straight
#
#      year_of_award                    award            movie  \
# 338           1937  Best Supporting Actress  Anthony Adverse
# 339           1938  Best Supporting Actress   In Old Chicago
# 340           1939  Best Supporting Actress          Jezebel
#
#                person  age_at_award  year_of_birth
# 338  Gale Sondergaard          38.0         1899.0
# 339       Alice Brady          46.0         1892.0
# 340       Fay Bainter          48.0         1891.0

# %%
grouped['race_ethnicity'].max()
# Out:
# award
# Best Actor                 White
# Best Actress               White
# Best Director              White
# Best Supporting Actor      White
# Best Supporting Actress    White
# Name: race_ethnicity, dtype: object

# %%
for age_at_award, group in grouped:
        print(age_at_award)
        display(group.sort_values('age_at_award',ascending=False).head(3))
# Out:
# Best Actor
#            birthplace date_of_birth race_ethnicity        religion  \
# 140  Grand Island, Ne    2005-05-16          White              Na
# 128     Winterset, Ia    2007-05-26          White  Roman Catholic
# 89    London, England    1868-04-10          White              Na
#
#     sexual_orientation  year_of_award       award           movie  \
# 140           Straight           1982  Best Actor  On Golden Pond
# 128           Straight           1970  Best Actor       True Grit
# 89            Straight           1930  Best Actor        Desraeli
#
#             person  age_at_award  year_of_birth
# 140    Henry Fonda          77.0         1905.0
# 128     John Wayne          63.0         1907.0
# 89   George Arliss          62.0         1868.0
# Best Actress
#           birthplace date_of_birth race_ethnicity religion sexual_orientation  \
# 313  London, England    2009-06-07          White       Na           Straight
# 305     Hartford, Ct    2007-05-12          White  Atheist           Bisexual
# 335       Summit, Nj    2049-06-22          White       Na           Straight
#
#      year_of_award         award               movie             person  \
# 313           1990  Best Actress  Driving Miss Daisy      Jessica Tandy
# 305           1982  Best Actress      On Golden Pond  Katharine Hepburn
# 335           2012  Best Actress       The Iron Lady       Meryl Streep
#
#      age_at_award  year_of_birth
# 313          81.0         1909.0
# 305          75.0         1907.0
# 335          63.0         1949.0
# Best Director
#            birthplace date_of_birth race_ethnicity  religion  \
# 78  San Francisco, Ca    2030-05-31          White        Na
# 76      Paris, France    2033-08-18          White  See Note
# 37      New York City    1899-07-07          White        Na
#
#    sexual_orientation  year_of_award          award                movie  \
# 78           Straight           2005  Best Director  Million Dollar Baby
# 76           Straight           2003  Best Director          The Pianist
# 37                Gay           1965  Best Director         My Fair Lady
#
#             person  age_at_award  year_of_birth
# 78  Clint Eastwood          75.0         1930.0
# 76  Roman Polanski          70.0         1933.0
# 37    George Cukor          66.0         1899.0
# Best Supporting Actor
#                    birthplace date_of_birth race_ethnicity        religion  \
# 248  Toronto, Ontario, Canada    2029-12-13          White              Na
# 222               Kenosha, Wi    2004-05-31          White  Roman Catholic
# 212             New York City    1896-01-20          White          Jewish
#
#     sexual_orientation  year_of_award                  award  \
# 248           Straight           2012  Best Supporting Actor
# 222           Straight           1986  Best Supporting Actor
# 212           Straight           1976  Best Supporting Actor
#
#                  movie               person  age_at_award  year_of_birth
# 248          Beginning  Christopher Plummer          83.0         1929.0
# 222             Cocoon           Don Ameche          82.0         1904.0
# 212  The Sunshine Boys         George Burns          80.0         1896.0
# Best Supporting Actress
#                    birthplace date_of_birth race_ethnicity  religion  \
# 386  Croydon, Surrey, England    2007-12-22          White  Agnostic
# 370                Quincy, Ma    1896-10-30          White        Na
# 365           London, England    1892-05-11          White        Na
#
#     sexual_orientation  year_of_award                    award  \
# 386           Straight           1985  Best Supporting Actress
# 370           Straight           1969  Best Supporting Actress
# 365           Straight           1964  Best Supporting Actress
#
#                   movie               person  age_at_award  year_of_birth
# 386  A Passage to India       Peggy Ashcroft          78.0         1907.0
# 370     Rosemary's Baby          Ruth Gordon          73.0         1896.0
# 365         the V.I.P.s  Margaret Rutherford          72.0         1892.0

# %% [markdown]
# #
# ###  Transform
# #

# %%
oscars_short.head(3)
# Out:
#           birthplace date_of_birth race_ethnicity religion sexual_orientation  \
# 0  Chisinau, Moldova    1895-09-30          White       Na           Straight
# 1  Glasgow, Scotland    1886-02-02          White       Na           Straight
# 2  Chisinau, Moldova    1895-09-30          White       Na           Straight
#
#    year_of_award          award                           movie  \
# 0           1927  Best Director             Two Arabian Knights
# 1           1930  Best Director                 The Divine Lady
# 2           1931  Best Director  All Quiet on the Western Front
#
#             person  age_at_award  year_of_birth
# 0  Lewis Milestone          32.0         1895.0
# 1      Frank Lloyd          44.0         1886.0
# 2  Lewis Milestone          36.0         1895.0

# %%
grouped=oscars_short.groupby('award')
grouped['age_at_award'].mean()
# Out:
# award
# Best Actor                 45.046512
# Best Actress               36.850575
# Best Director              47.279070
# Best Supporting Actor      50.666667
# Best Supporting Actress    40.641026
# Name: age_at_award, dtype: float64

# %%
grouped['age_at_award'].transform('mean').head(20)
# Out:
# 0     47.27907
# 1     47.27907
# 2     47.27907
# 3     47.27907
# 4     47.27907
# 5     47.27907
# 6     47.27907
# 7     47.27907
# 8     47.27907
# 9     47.27907
# 10    47.27907
# 11    47.27907
# 12    47.27907
# 13    47.27907
# 14    47.27907
# 15    47.27907
# 16    47.27907
# 17    47.27907
# 18    47.27907
# 19    47.27907
# Name: age_at_award, dtype: float64

# %%
oscars_short['avg_age_at_award'] = oscars_short.groupby('award')['age_at_award'].transform('mean')
oscars_short['is_above_avg_age'] = oscars_short['avg_age_at_award'] < oscars_short['age_at_award']

# %%
oscars_short.head(20)
# Out:
#                              birthplace date_of_birth race_ethnicity  \
# 0                     Chisinau, Moldova    1895-09-30          White
# 1                     Glasgow, Scotland    1886-02-02          White
# 2                     Chisinau, Moldova    1895-09-30          White
# 3                           Chicago, Il    1899-02-23          White
# 4                    Salt Lake City, Ut    1894-04-23          White
# 5                     Glasgow, Scotland    1886-02-02          White
# 6             Bisacquino, Sicily, Italy    1897-05-18          White
# 7                    Cape Elizabeth, Me    1894-02-01          White
# 8             Bisacquino, Sicily, Italy    1897-05-18          White
# 9                       Los Angeles, Ca    1898-10-03          White
# 10            Bisacquino, Sicily, Italy    1897-05-18          White
# 11                         Pasadena, Ca    1883-02-23          White
# 12                   Cape Elizabeth, Me    1894-02-01          White
# 13                   Cape Elizabeth, Me    1894-02-01          White
# 14  Mulhouse, Haut-Rhin, Alsace, France    1902-07-01          White
# 15                    Budapest, Hungary    1886-12-24          White
# 16                      Los Angeles, Ca    1898-10-03          White
# 17                        New York City    2018-10-11          White
# 18              Sucha, Galicia, Austria    2006-06-22          White
# 19  Mulhouse, Haut-Rhin, Alsace, France    1902-07-01          White
#
#           religion sexual_orientation  year_of_award          award  \
# 0               Na           Straight           1927  Best Director
# 1               Na           Straight           1930  Best Director
# 2               Na           Straight           1931  Best Director
# 3               Na           Straight           1932  Best Director
# 4   Roman Catholic           Straight           1933  Best Director
# 5               Na           Straight           1934  Best Director
# 6   Roman Catholic           Straight           1935  Best Director
# 7   Roman Catholic           Bisexual           1936  Best Director
# 8   Roman Catholic           Straight           1937  Best Director
# 9               Na           Straight           1938  Best Director
# 10  Roman Catholic           Straight           1939  Best Director
# 11              Na           Straight           1940  Best Director
# 12  Roman Catholic           Bisexual           1941  Best Director
# 13  Roman Catholic           Bisexual           1942  Best Director
# 14              Na           Straight           1943  Best Director
# 15              Na           Straight           1944  Best Director
# 16              Na           Straight           1945  Best Director
# 17          Jewish                Gay           1962  Best Director
# 18          Jewish           Straight           1946  Best Director
# 19              Na           Straight           1947  Best Director
#
#                              movie           person  age_at_award  \
# 0              Two Arabian Knights  Lewis Milestone          32.0
# 1                  The Divine Lady      Frank Lloyd          44.0
# 2   All Quiet on the Western Front  Lewis Milestone          36.0
# 3                           Skippy    Norman Taurog          33.0
# 4                         Bad Girl    Frank Borzage          39.0
# 5                        Cavalcade      Frank Lloyd          48.0
# 6            It Happened One Night      Frank Capra          38.0
# 7                     The Informer        John Ford          42.0
# 8           Mr. Deeds Goes to Town      Frank Capra          40.0
# 9                  The Awful Truth      Leo McCarey          40.0
# 10      You Can't Take It with You      Frank Capra          42.0
# 11              Gone with the Wind   Victor Fleming          57.0
# 12             The Grapes of Wrath        John Ford          47.0
# 13         How Green Was My Valley        John Ford          48.0
# 14                    Mrs. Miniver    William Wyler          41.0
# 15                      Casablanca   Michael Curtiz          58.0
# 16                    Going My Way      Leo McCarey          47.0
# 17                 West Side Story   Jerome Robbins          44.0
# 18                The Lost Weekend     Billy Wilder          40.0
# 19     The Best Years of Our Lives    William Wyler          45.0
#
#     year_of_birth  avg_age_at_award  is_above_avg_age
# 0          1895.0          47.27907             False
# 1          1886.0          47.27907             False
# 2          1895.0          47.27907             False
# 3          1899.0          47.27907             False
# 4          1894.0          47.27907             False
# 5          1886.0          47.27907              True
# 6          1897.0          47.27907             False
# 7          1894.0          47.27907             False
# 8          1897.0          47.27907             False
# 9          1898.0          47.27907             False
# 10         1897.0          47.27907             False
# 11         1883.0          47.27907              True
# 12         1894.0          47.27907             False
# 13         1894.0          47.27907              True
# 14         1902.0          47.27907             False
# 15         1886.0          47.27907              True
# 16         1898.0          47.27907             False
# 17         1918.0          47.27907             False
# 18         1906.0          47.27907             False
# 19         1902.0          47.27907             False

# %% [markdown]
# Transform can also be used to do transformations to a dataframe, in combination with apply

# %%
#Let´s imagine we want to add 1 to the year of birth (just to see how to do it)
oscars_short['year_of_birth'].transform(func = lambda x : x + 1)
# Out:
# 0      1896.0
# 1      1887.0
# 2      1896.0
# 3      1900.0
# 4      1895.0
#         ...
# 411    1968.0
# 412    1961.0
# 413    1973.0
# 414    1983.0
# 415    1984.0
# Name: year_of_birth, Length: 416, dtype: float64

# %% [markdown]
# We can then assign this serie to the old year_of_birth column, or to a new one.
#
# Transform comes in handy during feature extraction. It can replace groupby + merge operation, all in one.

# %% [markdown]
# #
# #
# #
# #
# # Combining Pandas Objects
# #
# To do this, we will work with _append, concat, join_ and _merge_
#
# The first one we will use is append, which allows us to add one or more rows to a dataframe. We can manually add one row at a time with .loc, but we will be able to add several rows (or even indicate them with a second df) using append

# %%
oscars_short_BestActress=oscars_short.loc[oscars_short['award'].str.contains('Best Actress'),:]
oscars_short_BestActor=oscars_short.loc[oscars_short['award'].str.contains('Best Actor'),:]

# %%
oscars_short_BestActress.head()
# Out:
#                    birthplace date_of_birth race_ethnicity religion  \
# 251          Philadelphia, Pa    2006-10-06          White       Na
# 252  Toronto, Ontario, Canada    1892-04-08          White       Na
# 253  Montreal, Quebec, Canada    1902-08-10          White       Na
# 254  Cobourg, Ontario, Canada    1868-11-02          White       Na
# 255            Washington, Dc    1900-10-10          White       Na
#
#     sexual_orientation  year_of_award         award  \
# 251           Straight           1929  Best Actress
# 252           Straight           1930  Best Actress
# 253           Straight           1930  Best Actress
# 254           Straight           1931  Best Actress
# 255           Straight           1932  Best Actress
#
#                           movie          person  age_at_award  year_of_birth  \
# 251                  7th Heaven    Janet Gaynor          23.0         1906.0
# 252                    Coquette   Mary Pickford          38.0         1892.0
# 253                The Divorcee   Norma Shearer          28.0         1902.0
# 254                Min and Bill  Marie Dressler          63.0         1868.0
# 255  The Sin of Madelon Claudet     Helen Hayes          32.0         1900.0
#
#      avg_age_at_award  is_above_avg_age
# 251         36.850575             False
# 252         36.850575              True
# 253         36.850575             False
# 254         36.850575              True
# 255         36.850575             False

# %%
oscars_short_BestActor.head()
# Out:
#                 birthplace date_of_birth race_ethnicity        religion  \
# 87  Rorschach, Switzerland    1884-07-23          White              Na
# 88            Columbus, Oh    1889-03-29          White              Na
# 89         London, England    1868-04-10          White              Na
# 90        Philadelphia, Pa    1878-04-28          White  Roman Catholic
# 91         Kansas City, Mo    1885-04-01          White              Na
#
#    sexual_orientation  year_of_award       award             movie  \
# 87           Bisexual           1929  Best Actor  The Last Command
# 88           Straight           1930  Best Actor    In Old Arizona
# 89           Straight           1930  Best Actor          Desraeli
# 90           Straight           1931  Best Actor       A Free Soul
# 91           Straight           1932  Best Actor         The Champ
#
#               person  age_at_award  year_of_birth  avg_age_at_award  \
# 87     Emil Jannings          45.0         1884.0         45.046512
# 88     Warner Baxter          41.0         1889.0         45.046512
# 89     George Arliss          62.0         1868.0         45.046512
# 90  Lionel Barrymore          53.0         1878.0         45.046512
# 91     Wallace Beery          47.0         1885.0         45.046512
#
#     is_above_avg_age
# 87             False
# 88             False
# 89              True
# 90              True
# 91              True

# %%
oscars_short_Best_ActorandActress=oscars_short_BestActor.append(oscars_short_BestActress)

# %%
oscars_short_Best_ActorandActress
# Out:
#                          birthplace date_of_birth race_ethnicity  \
# 87           Rorschach, Switzerland    1884-07-23          White
# 88                     Columbus, Oh    1889-03-29          White
# 89                  London, England    1868-04-10          White
# 90                 Philadelphia, Pa    1878-04-28          White
# 91                  Kansas City, Mo    1885-04-01          White
# ..                              ...           ...            ...
# 333                   Arlington, Va    2064-07-26          White
# 334               Jerusalem, Israel    1981-06-09          White
# 335                      Summit, Nj    2049-06-22          White
# 336                  Louisville, Ky    1990-08-15          White
# 337  Melbourne, Victoria, Australia    2069-05-14          White
#
#            religion sexual_orientation  year_of_award         award  \
# 87               Na           Bisexual           1929    Best Actor
# 88               Na           Straight           1930    Best Actor
# 89               Na           Straight           1930    Best Actor
# 90   Roman Catholic           Straight           1931    Best Actor
# 91               Na           Straight           1932    Best Actor
# ..              ...                ...            ...           ...
# 333              Na           Straight           2010  Best Actress
# 334          Jewish           Straight           2011  Best Actress
# 335              Na           Straight           2012  Best Actress
# 336              Na                 Na           2013  Best Actress
# 337              Na           Straight           2014  Best Actress
#
#                        movie             person  age_at_award  year_of_birth  \
# 87          The Last Command      Emil Jannings          45.0         1884.0
# 88            In Old Arizona      Warner Baxter          41.0         1889.0
# 89                  Desraeli      George Arliss          62.0         1868.0
# 90               A Free Soul   Lionel Barrymore          53.0         1878.0
# 91                 The Champ      Wallace Beery          47.0         1885.0
# ..                       ...                ...           ...            ...
# 333           The Blind Side     Sandra Bullock          46.0         1964.0
# 334               Black Swan    Natalie Portman          30.0         1981.0
# 335            The Iron Lady       Meryl Streep          63.0         1949.0
# 336  Silver Linings Playbook  Jennifer Lawrence          23.0         1990.0
# 337             Blue Jasmine     Cate Blanchett          45.0         1969.0
#
#      avg_age_at_award  is_above_avg_age
# 87          45.046512             False
# 88          45.046512             False
# 89          45.046512              True
# 90          45.046512              True
# 91          45.046512              True
# ..                ...               ...
# 333         36.850575              True
# 334         36.850575             False
# 335         36.850575              True
# 336         36.850575             False
# 337         36.850575              True
#
# [173 rows x 13 columns]

# %%
len(oscars_short_BestActor)
# Out:
# 86

# %%
len(oscars_short_BestActress)
# Out:
# 87

# %%
86+87
# Out:
# 173

# %% [markdown]
# ### Concat
#
# We will see how to do the same (and more) using concat

# %%
oscars_short_BestActress.head()
# Out:
#                    birthplace date_of_birth race_ethnicity religion  \
# 251          Philadelphia, Pa    2006-10-06          White       Na
# 252  Toronto, Ontario, Canada    1892-04-08          White       Na
# 253  Montreal, Quebec, Canada    1902-08-10          White       Na
# 254  Cobourg, Ontario, Canada    1868-11-02          White       Na
# 255            Washington, Dc    1900-10-10          White       Na
#
#     sexual_orientation  year_of_award         award  \
# 251           Straight           1929  Best Actress
# 252           Straight           1930  Best Actress
# 253           Straight           1930  Best Actress
# 254           Straight           1931  Best Actress
# 255           Straight           1932  Best Actress
#
#                           movie          person  age_at_award  year_of_birth  \
# 251                  7th Heaven    Janet Gaynor          23.0         1906.0
# 252                    Coquette   Mary Pickford          38.0         1892.0
# 253                The Divorcee   Norma Shearer          28.0         1902.0
# 254                Min and Bill  Marie Dressler          63.0         1868.0
# 255  The Sin of Madelon Claudet     Helen Hayes          32.0         1900.0
#
#      avg_age_at_award  is_above_avg_age
# 251         36.850575             False
# 252         36.850575              True
# 253         36.850575             False
# 254         36.850575              True
# 255         36.850575             False

# %%
oscars_short_Best_ActorandActress_concat=pd.concat([oscars_short_BestActor,oscars_short_BestActress])

# %%
oscars_short_Best_ActorandActress_concat
# Out:
#                          birthplace date_of_birth race_ethnicity  \
# 87           Rorschach, Switzerland    1884-07-23          White
# 88                     Columbus, Oh    1889-03-29          White
# 89                  London, England    1868-04-10          White
# 90                 Philadelphia, Pa    1878-04-28          White
# 91                  Kansas City, Mo    1885-04-01          White
# ..                              ...           ...            ...
# 333                   Arlington, Va    2064-07-26          White
# 334               Jerusalem, Israel    1981-06-09          White
# 335                      Summit, Nj    2049-06-22          White
# 336                  Louisville, Ky    1990-08-15          White
# 337  Melbourne, Victoria, Australia    2069-05-14          White
#
#            religion sexual_orientation  year_of_award         award  \
# 87               Na           Bisexual           1929    Best Actor
# 88               Na           Straight           1930    Best Actor
# 89               Na           Straight           1930    Best Actor
# 90   Roman Catholic           Straight           1931    Best Actor
# 91               Na           Straight           1932    Best Actor
# ..              ...                ...            ...           ...
# 333              Na           Straight           2010  Best Actress
# 334          Jewish           Straight           2011  Best Actress
# 335              Na           Straight           2012  Best Actress
# 336              Na                 Na           2013  Best Actress
# 337              Na           Straight           2014  Best Actress
#
#                        movie             person  age_at_award  year_of_birth  \
# 87          The Last Command      Emil Jannings          45.0         1884.0
# 88            In Old Arizona      Warner Baxter          41.0         1889.0
# 89                  Desraeli      George Arliss          62.0         1868.0
# 90               A Free Soul   Lionel Barrymore          53.0         1878.0
# 91                 The Champ      Wallace Beery          47.0         1885.0
# ..                       ...                ...           ...            ...
# 333           The Blind Side     Sandra Bullock          46.0         1964.0
# 334               Black Swan    Natalie Portman          30.0         1981.0
# 335            The Iron Lady       Meryl Streep          63.0         1949.0
# 336  Silver Linings Playbook  Jennifer Lawrence          23.0         1990.0
# 337             Blue Jasmine     Cate Blanchett          45.0         1969.0
#
#      avg_age_at_award  is_above_avg_age
# 87          45.046512             False
# 88          45.046512             False
# 89          45.046512              True
# 90          45.046512              True
# 91          45.046512              True
# ..                ...               ...
# 333         36.850575              True
# 334         36.850575             False
# 335         36.850575              True
# 336         36.850575             False
# 337         36.850575              True
#
# [173 rows x 13 columns]

# %% [markdown]
# ![](Data/Yelp/join-or-merge-in-python-pandas-1.png)

# %%
grouped=oscars_short.groupby(['year_of_award']).agg({'age_at_award':['mean','count']})
level0=grouped.columns.get_level_values(0)
level1=grouped.columns.get_level_values(1)
grouped.columns = level0 + '_' + level1
grouped.reset_index(inplace=True)

# %%
grouped
# Out:
#     year_of_award  age_at_award_mean  age_at_award_count
# 0            1927          32.000000                   1
# 1            1929          34.000000                   2
# 2            1930          42.600000                   5
# 3            1931          50.666667                   3
# 4            1932          37.333333                   3
# ..            ...                ...                 ...
# 82           2010          51.000000                   4
# 83           2011          41.600000                   5
# 84           2012          54.200000                   5
# 85           2013          45.200000                   5
# 86           2014          41.000000                   4
#
# [87 rows x 3 columns]

# %% [markdown]
# As we want the records of both dataframes, we will use outer join

# %%
oscars_short_perYear=oscars_short.merge(grouped, left_on='year_of_award', right_on='year_of_award',how='outer')

# %%
oscars_short_perYear.head()
# Out:
#                  birthplace date_of_birth race_ethnicity religion  \
# 0         Chisinau, Moldova    1895-09-30          White       Na
# 1         Glasgow, Scotland    1886-02-02          White       Na
# 2              Columbus, Oh    1889-03-29          White       Na
# 3           London, England    1868-04-10          White       Na
# 4  Toronto, Ontario, Canada    1892-04-08          White       Na
#
#   sexual_orientation  year_of_award          award                movie  \
# 0           Straight           1927  Best Director  Two Arabian Knights
# 1           Straight           1930  Best Director      The Divine Lady
# 2           Straight           1930     Best Actor       In Old Arizona
# 3           Straight           1930     Best Actor             Desraeli
# 4           Straight           1930   Best Actress             Coquette
#
#             person  age_at_award  year_of_birth  avg_age_at_award  \
# 0  Lewis Milestone          32.0         1895.0         47.279070
# 1      Frank Lloyd          44.0         1886.0         47.279070
# 2    Warner Baxter          41.0         1889.0         45.046512
# 3    George Arliss          62.0         1868.0         45.046512
# 4    Mary Pickford          38.0         1892.0         36.850575
#
#    is_above_avg_age  age_at_award_mean  age_at_award_count
# 0             False               32.0                   1
# 1             False               42.6                   5
# 2             False               42.6                   5
# 3              True               42.6                   5
# 4              True               42.6                   5

# %% [markdown]
# If we want to obtain only the awards for the years when the average age was less than 40 we can do...

# %%
year_less_than_40=grouped.loc[grouped['age_at_award_mean']<40,:]

# %%
year_less_than_40
# Out:
#     year_of_award  age_at_award_mean  age_at_award_count
# 0            1927          32.000000                   1
# 1            1929          34.000000                   2
# 4            1932          37.333333                   3
# 5            1933          39.000000                   1
# 6            1934          36.666667                   3
# 7            1935          34.666667                   3
# 9            1937          36.750000                   4
# 10           1938          39.666667                   6
# 12           1940          39.500000                   6
# 15           1943          35.750000                   4
# 19           1947          36.600000                   5
# 22           1950          39.000000                   5
# 26           1954          36.000000                   5
# 27           1955          34.800000                   5
# 28           1956          39.200000                   5
# 30           1958          38.000000                   5
# 34           1962          32.600000                   5
# 53           1981          32.600000                   5
# 55           1983          39.600000                   5
# 66           1994          36.400000                   5
# 68           1996          37.600000                   5
# 72           2000          38.800000                   5
# 73           2001          37.000000                   5
# 76           2004          38.250000                   4

# %% [markdown]
# Merge operation, by default is inner

# %%
oscars_short.merge(year_less_than_40, left_on='year_of_award', right_on='year_of_award')
# Out:
#                  birthplace date_of_birth race_ethnicity        religion  \
# 0         Chisinau, Moldova    1895-09-30          White              Na
# 1               Chicago, Il    1899-02-23          White              Na
# 2           Kansas City, Mo    1885-04-01          White              Na
# 3            Washington, Dc    1900-10-10          White              Na
# 4        Salt Lake City, Ut    1894-04-23          White  Roman Catholic
# ..                      ...           ...            ...             ...
# 97          West Covina, Ca    2058-10-16          White  Roman Catholic
# 98     Benoni, South Africa    1975-08-07          White              Na
# 99                 Katy, Tx    2069-04-25          White              Na
# 100  Rorschach, Switzerland    1884-07-23          White              Na
# 101        Philadelphia, Pa    2006-10-06          White              Na
#
#     sexual_orientation  year_of_award                    award  \
# 0             Straight           1927            Best Director
# 1             Straight           1932            Best Director
# 2             Straight           1932               Best Actor
# 3             Straight           1932             Best Actress
# 4             Straight           1933            Best Director
# ..                 ...            ...                      ...
# 97            Straight           2004    Best Supporting Actor
# 98            Straight           2004             Best Actress
# 99            Straight           2004  Best Supporting Actress
# 100           Bisexual           1929               Best Actor
# 101           Straight           1929             Best Actress
#
#                           movie            person  age_at_award  \
# 0           Two Arabian Knights   Lewis Milestone          32.0
# 1                        Skippy     Norman Taurog          33.0
# 2                     The Champ     Wallace Beery          47.0
# 3    The Sin of Madelon Claudet       Helen Hayes          32.0
# 4                      Bad Girl     Frank Borzage          39.0
# ..                          ...               ...           ...
# 97                 Mystic River       Tim Robbins          46.0
# 98                      Monster   Charlize Theron          29.0
# 99                Cold Mountain  RenÌ©e Zellweger          35.0
# 100            The Last Command     Emil Jannings          45.0
# 101                  7th Heaven      Janet Gaynor          23.0
#
#      year_of_birth  avg_age_at_award  is_above_avg_age  age_at_award_mean  \
# 0           1895.0         47.279070             False          32.000000
# 1           1899.0         47.279070             False          37.333333
# 2           1885.0         45.046512              True          37.333333
# 3           1900.0         36.850575             False          37.333333
# 4           1894.0         47.279070             False          39.000000
# ..             ...               ...               ...                ...
# 97          1958.0         50.666667             False          38.250000
# 98          1975.0         36.850575             False          38.250000
# 99          1969.0         40.641026             False          38.250000
# 100         1884.0         45.046512             False          34.000000
# 101         1906.0         36.850575             False          34.000000
#
#      age_at_award_count
# 0                     1
# 1                     3
# 2                     3
# 3                     3
# 4                     1
# ..                  ...
# 97                    4
# 98                    4
# 99                    4
# 100                   2
# 101                   2
#
# [102 rows x 15 columns]
